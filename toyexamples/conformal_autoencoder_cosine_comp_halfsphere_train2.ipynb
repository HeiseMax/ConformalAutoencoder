# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ConformalAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere
from metrics import evaluate_conformality, conformality_jacobian_loss

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
data, labels = make_half_sphere(n_samples=3000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
val_data, val_labels = make_half_sphere(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5)
ax.set_title("Original Data in 3D")
ax.view_init(0, 180, 0)
plt.show()

# %%
# define model parameters
latent_dim = 2
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 128

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)


dir_path = "models/conformal_autoencoder_cosine_comp_halfsphere_train2"

# %%
lambda_isos = np.logspace(-3, 2, 9)
lambda_isos = np.concat([np.zeros(1), lambda_isos])

# %%
from metrics import conformality_cosine_loss

# %%
import os

def modelpath(dir_path, lambda_iso, index):
    os.makedirs(dir_path, exist_ok=True)
    return f"{dir_path}/lambda_{lambda_iso:.3f}_model_{index+1}.pth"

# %%
num_epochs = 1000
# train same model multiple times to average results
num_models = 4

recon_errors = []
regularization_errors = []
reg_metrics = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    reg_metric = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
        model.conformality_loss = conformality_cosine_loss

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = modelpath(dir_path, lambda_iso, j)
        model.save_checkpoint(model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.conformality_loss(model.decoder, encoded_data).item()
        
        reg_metric += conformality_jacobian_loss(model.decoder, encoded_data).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
    reg_metrics.append(reg_metric/num_models)
# Out:
# Training model 1/4 with lambda_iso=0.000
# /home/maxheise/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [100/1000], Loss: 0.00087082, Reconstruction Loss: 0.00087083, Conformal Loss: 0.02116907, Regularization Loss: 0.01448648
# Epoch [100/1000], Validation Loss: 0.00110221, Reconstruction Loss: 0.00110221, Conformal Loss: 0.02050501, Regularization Loss: 0.00509351
# Epoch [200/1000], Loss: 0.00082542, Reconstruction Loss: 0.00082542, Conformal Loss: 0.02103403, Regularization Loss: 0.02910471
# Epoch [200/1000], Validation Loss: 0.00104298, Reconstruction Loss: 0.00104298, Conformal Loss: 0.02082094, Regularization Loss: 0.00598005
# Epoch [300/1000], Loss: 0.00080496, Reconstruction Loss: 0.00080496, Conformal Loss: 0.02193141, Regularization Loss: 0.02456460
# Epoch [300/1000], Validation Loss: 0.00102653, Reconstruction Loss: 0.00102653, Conformal Loss: 0.02192093, Regularization Loss: 0.02244249
# Epoch [400/1000], Loss: 0.00078480, Reconstruction Loss: 0.00078480, Conformal Loss: 0.02098124, Regularization Loss: 0.03318736
# Epoch [400/1000], Validation Loss: 0.00101213, Reconstruction Loss: 0.00101213, Conformal Loss: 0.02028616, Regularization Loss: 0.04277990
# Epoch [500/1000], Loss: 0.00078344, Reconstruction Loss: 0.00078344, Conformal Loss: 0.02072181, Regularization Loss: 0.02979472
# Epoch [500/1000], Validation Loss: 0.00100843, Reconstruction Loss: 0.00100843, Conformal Loss: 0.02028628, Regularization Loss: 0.00580254
# Epoch [600/1000], Loss: 0.00078134, Reconstruction Loss: 0.00078134, Conformal Loss: 0.02243896, Regularization Loss: 0.04784935
# Epoch [600/1000], Validation Loss: 0.00100565, Reconstruction Loss: 0.00100565, Conformal Loss: 0.01964461, Regularization Loss: 0.01274229
# Epoch [700/1000], Loss: 0.00077787, Reconstruction Loss: 0.00077787, Conformal Loss: 0.02020301, Regularization Loss: 0.03176890
# Epoch [700/1000], Validation Loss: 0.00100553, Reconstruction Loss: 0.00100553, Conformal Loss: 0.02115273, Regularization Loss: 0.04123304
# Epoch [800/1000], Loss: 0.00077496, Reconstruction Loss: 0.00077496, Conformal Loss: 0.02199048, Regularization Loss: 0.02326431
# Epoch [800/1000], Validation Loss: 0.00100435, Reconstruction Loss: 0.00100435, Conformal Loss: 0.02083535, Regularization Loss: 0.02500584
# Epoch [900/1000], Loss: 0.00077418, Reconstruction Loss: 0.00077418, Conformal Loss: 0.02039432, Regularization Loss: 0.02540267
# Epoch [900/1000], Validation Loss: 0.00100501, Reconstruction Loss: 0.00100501, Conformal Loss: 0.01828532, Regularization Loss: 0.01639497
# Epoch [1000/1000], Loss: 0.00077646, Reconstruction Loss: 0.00077646, Conformal Loss: 0.02097919, Regularization Loss: 0.02015675
# Epoch [1000/1000], Validation Loss: 0.00100468, Reconstruction Loss: 0.00100468, Conformal Loss: 0.01992695, Regularization Loss: 0.01369777
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.000_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.000 trained and saved.
# Training model 2/4 with lambda_iso=0.000
# Epoch [100/1000], Loss: 0.00086948, Reconstruction Loss: 0.00086948, Conformal Loss: 0.00864018, Regularization Loss: 0.04745908
# Epoch [100/1000], Validation Loss: 0.00106574, Reconstruction Loss: 0.00106574, Conformal Loss: 0.00814531, Regularization Loss: 0.04339868
# Epoch [200/1000], Loss: 0.00082839, Reconstruction Loss: 0.00082839, Conformal Loss: 0.00826226, Regularization Loss: 0.02273453
# Epoch [200/1000], Validation Loss: 0.00102053, Reconstruction Loss: 0.00102053, Conformal Loss: 0.00812462, Regularization Loss: 0.03979966
# Epoch [300/1000], Loss: 0.00080384, Reconstruction Loss: 0.00080384, Conformal Loss: 0.00814453, Regularization Loss: 0.02312225
# Epoch [300/1000], Validation Loss: 0.00106464, Reconstruction Loss: 0.00106464, Conformal Loss: 0.00868975, Regularization Loss: 0.02110518
# Epoch [400/1000], Loss: 0.00078684, Reconstruction Loss: 0.00078684, Conformal Loss: 0.00825981, Regularization Loss: 0.02183861
# Epoch [400/1000], Validation Loss: 0.00101596, Reconstruction Loss: 0.00101596, Conformal Loss: 0.00889581, Regularization Loss: 0.02874149
# Epoch [500/1000], Loss: 0.00078566, Reconstruction Loss: 0.00078566, Conformal Loss: 0.00823681, Regularization Loss: 0.02111517
# Epoch [500/1000], Validation Loss: 0.00101264, Reconstruction Loss: 0.00101264, Conformal Loss: 0.00800327, Regularization Loss: 0.02169789
# Epoch [600/1000], Loss: 0.00077393, Reconstruction Loss: 0.00077393, Conformal Loss: 0.00819273, Regularization Loss: 0.02774579
# Epoch [600/1000], Validation Loss: 0.00101056, Reconstruction Loss: 0.00101056, Conformal Loss: 0.00745714, Regularization Loss: 0.01838940
# Epoch [700/1000], Loss: 0.00077716, Reconstruction Loss: 0.00077716, Conformal Loss: 0.00783425, Regularization Loss: 0.02577618
# Epoch [700/1000], Validation Loss: 0.00101277, Reconstruction Loss: 0.00101277, Conformal Loss: 0.00870194, Regularization Loss: 0.04115687
# Epoch [800/1000], Loss: 0.00077549, Reconstruction Loss: 0.00077549, Conformal Loss: 0.00812819, Regularization Loss: 0.03182128
# Epoch [800/1000], Validation Loss: 0.00101158, Reconstruction Loss: 0.00101158, Conformal Loss: 0.00823696, Regularization Loss: 0.03710567
# Epoch [900/1000], Loss: 0.00077616, Reconstruction Loss: 0.00077616, Conformal Loss: 0.00897825, Regularization Loss: 0.02836285
# Epoch [900/1000], Validation Loss: 0.00101094, Reconstruction Loss: 0.00101094, Conformal Loss: 0.00736293, Regularization Loss: 0.03598294
# Epoch [1000/1000], Loss: 0.00077353, Reconstruction Loss: 0.00077353, Conformal Loss: 0.00894846, Regularization Loss: 0.03188273
# Epoch [1000/1000], Validation Loss: 0.00101081, Reconstruction Loss: 0.00101081, Conformal Loss: 0.00830815, Regularization Loss: 0.03691530
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.000_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.000 trained and saved.
# Training model 3/4 with lambda_iso=0.000
# Epoch [100/1000], Loss: 0.00085722, Reconstruction Loss: 0.00085722, Conformal Loss: 0.01936332, Regularization Loss: 0.01226390
# Epoch [100/1000], Validation Loss: 0.00107227, Reconstruction Loss: 0.00107227, Conformal Loss: 0.02037107, Regularization Loss: 0.01002038
# Epoch [200/1000], Loss: 0.00082619, Reconstruction Loss: 0.00082619, Conformal Loss: 0.02240788, Regularization Loss: 0.02069259
# Epoch [200/1000], Validation Loss: 0.00103048, Reconstruction Loss: 0.00103048, Conformal Loss: 0.02178880, Regularization Loss: 0.00095122
# Epoch [300/1000], Loss: 0.00081470, Reconstruction Loss: 0.00081470, Conformal Loss: 0.02291867, Regularization Loss: 0.00697969
# Epoch [300/1000], Validation Loss: 0.00102288, Reconstruction Loss: 0.00102288, Conformal Loss: 0.02089136, Regularization Loss: 0.02756046
# Epoch [400/1000], Loss: 0.00079066, Reconstruction Loss: 0.00079066, Conformal Loss: 0.02216704, Regularization Loss: 0.00808510
# Epoch [400/1000], Validation Loss: 0.00100521, Reconstruction Loss: 0.00100521, Conformal Loss: 0.01922980, Regularization Loss: 0.00621248
# Epoch [500/1000], Loss: 0.00078425, Reconstruction Loss: 0.00078425, Conformal Loss: 0.02297597, Regularization Loss: 0.00853105
# Epoch [500/1000], Validation Loss: 0.00100199, Reconstruction Loss: 0.00100199, Conformal Loss: 0.01876185, Regularization Loss: 0.04358464
# Epoch [600/1000], Loss: 0.00077855, Reconstruction Loss: 0.00077855, Conformal Loss: 0.02122535, Regularization Loss: 0.02422222
# Epoch [600/1000], Validation Loss: 0.00100717, Reconstruction Loss: 0.00100717, Conformal Loss: 0.02161358, Regularization Loss: 0.00081931
# Epoch [700/1000], Loss: 0.00077639, Reconstruction Loss: 0.00077639, Conformal Loss: 0.02148130, Regularization Loss: 0.01091839
# Epoch [700/1000], Validation Loss: 0.00100440, Reconstruction Loss: 0.00100440, Conformal Loss: 0.02015646, Regularization Loss: 0.00372984
# Epoch [800/1000], Loss: 0.00077834, Reconstruction Loss: 0.00077834, Conformal Loss: 0.02245163, Regularization Loss: 0.01716246
# Epoch [800/1000], Validation Loss: 0.00100244, Reconstruction Loss: 0.00100244, Conformal Loss: 0.02089449, Regularization Loss: 0.02045646
# Epoch [900/1000], Loss: 0.00078243, Reconstruction Loss: 0.00078243, Conformal Loss: 0.02044309, Regularization Loss: 0.00969803
# Epoch [900/1000], Validation Loss: 0.00100316, Reconstruction Loss: 0.00100316, Conformal Loss: 0.02257392, Regularization Loss: 0.00914249
# Epoch [1000/1000], Loss: 0.00077578, Reconstruction Loss: 0.00077578, Conformal Loss: 0.02238015, Regularization Loss: 0.00998795
# Epoch [1000/1000], Validation Loss: 0.00100288, Reconstruction Loss: 0.00100288, Conformal Loss: 0.02243894, Regularization Loss: 0.00167559
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.000_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.000 trained and saved.
# Training model 4/4 with lambda_iso=0.000
# Epoch [100/1000], Loss: 0.00088232, Reconstruction Loss: 0.00088232, Conformal Loss: 0.00627787, Regularization Loss: 0.14029790
# Epoch [100/1000], Validation Loss: 0.00109739, Reconstruction Loss: 0.00109739, Conformal Loss: 0.00605455, Regularization Loss: 0.08514942
# Epoch [200/1000], Loss: 0.00085426, Reconstruction Loss: 0.00085426, Conformal Loss: 0.00639587, Regularization Loss: 0.09625348
# Epoch [200/1000], Validation Loss: 0.00104411, Reconstruction Loss: 0.00104411, Conformal Loss: 0.00744557, Regularization Loss: 0.17115051
# Epoch [300/1000], Loss: 0.00081615, Reconstruction Loss: 0.00081615, Conformal Loss: 0.00625198, Regularization Loss: 0.14657547
# Epoch [300/1000], Validation Loss: 0.00101671, Reconstruction Loss: 0.00101671, Conformal Loss: 0.00657050, Regularization Loss: 0.19293556
# Epoch [400/1000], Loss: 0.00080443, Reconstruction Loss: 0.00080443, Conformal Loss: 0.00640209, Regularization Loss: 0.13416462
# Epoch [400/1000], Validation Loss: 0.00099875, Reconstruction Loss: 0.00099875, Conformal Loss: 0.00628269, Regularization Loss: 0.20880382
# Epoch [500/1000], Loss: 0.00080316, Reconstruction Loss: 0.00080316, Conformal Loss: 0.00687036, Regularization Loss: 0.17582555
# Epoch [500/1000], Validation Loss: 0.00099603, Reconstruction Loss: 0.00099603, Conformal Loss: 0.00637510, Regularization Loss: 0.09333789
# Epoch [600/1000], Loss: 0.00079841, Reconstruction Loss: 0.00079841, Conformal Loss: 0.00715349, Regularization Loss: 0.11834650
# Epoch [600/1000], Validation Loss: 0.00099630, Reconstruction Loss: 0.00099630, Conformal Loss: 0.00696767, Regularization Loss: 0.15670121
# Epoch [700/1000], Loss: 0.00079173, Reconstruction Loss: 0.00079173, Conformal Loss: 0.00681724, Regularization Loss: 0.14724390
# Epoch [700/1000], Validation Loss: 0.00099326, Reconstruction Loss: 0.00099326, Conformal Loss: 0.00614958, Regularization Loss: 0.13160983
# Epoch [800/1000], Loss: 0.00078597, Reconstruction Loss: 0.00078597, Conformal Loss: 0.00661699, Regularization Loss: 0.13248420
# Epoch [800/1000], Validation Loss: 0.00099371, Reconstruction Loss: 0.00099371, Conformal Loss: 0.00699679, Regularization Loss: 0.22032273
# Epoch [900/1000], Loss: 0.00079600, Reconstruction Loss: 0.00079600, Conformal Loss: 0.00725229, Regularization Loss: 0.13209422
# Epoch [900/1000], Validation Loss: 0.00099406, Reconstruction Loss: 0.00099406, Conformal Loss: 0.00620158, Regularization Loss: 0.14238860
# Epoch [1000/1000], Loss: 0.00078430, Reconstruction Loss: 0.00078430, Conformal Loss: 0.00640009, Regularization Loss: 0.17475583
# Epoch [1000/1000], Validation Loss: 0.00099367, Reconstruction Loss: 0.00099367, Conformal Loss: 0.00751087, Regularization Loss: 0.08491235
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.000_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.000 trained and saved.
# Training model 1/4 with lambda_iso=0.001
# Epoch [100/1000], Loss: 0.00088090, Reconstruction Loss: 0.00087536, Conformal Loss: 0.00554316, Regularization Loss: 0.02439564
# Epoch [100/1000], Validation Loss: 0.00110822, Reconstruction Loss: 0.00110094, Conformal Loss: 0.00727663, Regularization Loss: 0.03049115
# Epoch [200/1000], Loss: 0.00087948, Reconstruction Loss: 0.00087463, Conformal Loss: 0.00484539, Regularization Loss: 0.01450376
# Epoch [200/1000], Validation Loss: 0.00106869, Reconstruction Loss: 0.00106113, Conformal Loss: 0.00755865, Regularization Loss: 0.01589330
# Epoch [300/1000], Loss: 0.00082234, Reconstruction Loss: 0.00081668, Conformal Loss: 0.00565862, Regularization Loss: 0.01802083
# Epoch [300/1000], Validation Loss: 0.00107192, Reconstruction Loss: 0.00106581, Conformal Loss: 0.00610850, Regularization Loss: 0.00548126
# Epoch [400/1000], Loss: 0.00079882, Reconstruction Loss: 0.00079392, Conformal Loss: 0.00489968, Regularization Loss: 0.01407054
# Epoch [400/1000], Validation Loss: 0.00103349, Reconstruction Loss: 0.00102694, Conformal Loss: 0.00654800, Regularization Loss: 0.01371790
# Epoch [500/1000], Loss: 0.00079418, Reconstruction Loss: 0.00078856, Conformal Loss: 0.00561259, Regularization Loss: 0.02325630
# Epoch [500/1000], Validation Loss: 0.00102943, Reconstruction Loss: 0.00102451, Conformal Loss: 0.00492064, Regularization Loss: 0.02338918
# Epoch [600/1000], Loss: 0.00078929, Reconstruction Loss: 0.00078419, Conformal Loss: 0.00509572, Regularization Loss: 0.01624444
# Epoch [600/1000], Validation Loss: 0.00102527, Reconstruction Loss: 0.00101992, Conformal Loss: 0.00535176, Regularization Loss: 0.02286141
# Epoch [700/1000], Loss: 0.00078361, Reconstruction Loss: 0.00077870, Conformal Loss: 0.00491034, Regularization Loss: 0.02112400
# Epoch [700/1000], Validation Loss: 0.00102730, Reconstruction Loss: 0.00102160, Conformal Loss: 0.00570495, Regularization Loss: 0.01396596
# Epoch [800/1000], Loss: 0.00078251, Reconstruction Loss: 0.00077752, Conformal Loss: 0.00498950, Regularization Loss: 0.01771618
# Epoch [800/1000], Validation Loss: 0.00102668, Reconstruction Loss: 0.00102123, Conformal Loss: 0.00545127, Regularization Loss: 0.01605887
# Epoch [900/1000], Loss: 0.00078556, Reconstruction Loss: 0.00078098, Conformal Loss: 0.00458737, Regularization Loss: 0.00803030
# Epoch [900/1000], Validation Loss: 0.00102463, Reconstruction Loss: 0.00101980, Conformal Loss: 0.00482962, Regularization Loss: 0.01794343
# Epoch [1000/1000], Loss: 0.00078216, Reconstruction Loss: 0.00077712, Conformal Loss: 0.00504109, Regularization Loss: 0.02501360
# Epoch [1000/1000], Validation Loss: 0.00102553, Reconstruction Loss: 0.00101966, Conformal Loss: 0.00586729, Regularization Loss: 0.03286641
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.001_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.001 trained and saved.
# Training model 2/4 with lambda_iso=0.001
# Epoch [100/1000], Loss: 0.00094775, Reconstruction Loss: 0.00094187, Conformal Loss: 0.00587915, Regularization Loss: 0.03218466
# Epoch [100/1000], Validation Loss: 0.00113508, Reconstruction Loss: 0.00112983, Conformal Loss: 0.00525216, Regularization Loss: 0.05853818
# Epoch [200/1000], Loss: 0.00086456, Reconstruction Loss: 0.00085963, Conformal Loss: 0.00493463, Regularization Loss: 0.02456401
# Epoch [200/1000], Validation Loss: 0.00107473, Reconstruction Loss: 0.00106954, Conformal Loss: 0.00519275, Regularization Loss: 0.01676346
# Epoch [300/1000], Loss: 0.00082890, Reconstruction Loss: 0.00082451, Conformal Loss: 0.00439447, Regularization Loss: 0.02674481
# Epoch [300/1000], Validation Loss: 0.00105371, Reconstruction Loss: 0.00104831, Conformal Loss: 0.00540177, Regularization Loss: 0.03887583
# Epoch [400/1000], Loss: 0.00081299, Reconstruction Loss: 0.00080835, Conformal Loss: 0.00463716, Regularization Loss: 0.01038155
# Epoch [400/1000], Validation Loss: 0.00103189, Reconstruction Loss: 0.00102753, Conformal Loss: 0.00436377, Regularization Loss: 0.00957053
# Epoch [500/1000], Loss: 0.00080218, Reconstruction Loss: 0.00079747, Conformal Loss: 0.00471225, Regularization Loss: 0.01308245
# Epoch [500/1000], Validation Loss: 0.00102311, Reconstruction Loss: 0.00101739, Conformal Loss: 0.00572083, Regularization Loss: 0.02656207
# Epoch [600/1000], Loss: 0.00079717, Reconstruction Loss: 0.00079302, Conformal Loss: 0.00414396, Regularization Loss: 0.01110830
# Epoch [600/1000], Validation Loss: 0.00102149, Reconstruction Loss: 0.00101625, Conformal Loss: 0.00524119, Regularization Loss: 0.01267256
# Epoch [700/1000], Loss: 0.00079535, Reconstruction Loss: 0.00079137, Conformal Loss: 0.00398465, Regularization Loss: 0.00911483
# Epoch [700/1000], Validation Loss: 0.00102299, Reconstruction Loss: 0.00101763, Conformal Loss: 0.00536704, Regularization Loss: 0.01870882
# Epoch [800/1000], Loss: 0.00079193, Reconstruction Loss: 0.00078750, Conformal Loss: 0.00442468, Regularization Loss: 0.02098481
# Epoch [800/1000], Validation Loss: 0.00101948, Reconstruction Loss: 0.00101479, Conformal Loss: 0.00468605, Regularization Loss: 0.01776533
# Epoch [900/1000], Loss: 0.00079544, Reconstruction Loss: 0.00079120, Conformal Loss: 0.00423424, Regularization Loss: 0.02764852
# Epoch [900/1000], Validation Loss: 0.00101867, Reconstruction Loss: 0.00101378, Conformal Loss: 0.00488983, Regularization Loss: 0.00627775
# Epoch [1000/1000], Loss: 0.00078901, Reconstruction Loss: 0.00078464, Conformal Loss: 0.00437068, Regularization Loss: 0.01911427
# Epoch [1000/1000], Validation Loss: 0.00101813, Reconstruction Loss: 0.00101364, Conformal Loss: 0.00448382, Regularization Loss: 0.01651142
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.001_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.001 trained and saved.
# Training model 3/4 with lambda_iso=0.001
# Epoch [100/1000], Loss: 0.00088299, Reconstruction Loss: 0.00087628, Conformal Loss: 0.00670737, Regularization Loss: 0.01380446
# Epoch [100/1000], Validation Loss: 0.00107413, Reconstruction Loss: 0.00106615, Conformal Loss: 0.00798262, Regularization Loss: 0.02056855
# Epoch [200/1000], Loss: 0.00083994, Reconstruction Loss: 0.00083433, Conformal Loss: 0.00560699, Regularization Loss: 0.02050672
# Epoch [200/1000], Validation Loss: 0.00106768, Reconstruction Loss: 0.00106138, Conformal Loss: 0.00629952, Regularization Loss: 0.02593462
# Epoch [300/1000], Loss: 0.00081031, Reconstruction Loss: 0.00080460, Conformal Loss: 0.00570324, Regularization Loss: 0.04758263
# Epoch [300/1000], Validation Loss: 0.00102666, Reconstruction Loss: 0.00102080, Conformal Loss: 0.00585799, Regularization Loss: 0.05250953
# Epoch [400/1000], Loss: 0.00081094, Reconstruction Loss: 0.00080553, Conformal Loss: 0.00541409, Regularization Loss: 0.03411186
# Epoch [400/1000], Validation Loss: 0.00101902, Reconstruction Loss: 0.00101277, Conformal Loss: 0.00624902, Regularization Loss: 0.01973513
# Epoch [500/1000], Loss: 0.00080125, Reconstruction Loss: 0.00079596, Conformal Loss: 0.00529417, Regularization Loss: 0.02587570
# Epoch [500/1000], Validation Loss: 0.00101927, Reconstruction Loss: 0.00101375, Conformal Loss: 0.00551690, Regularization Loss: 0.05858785
# Epoch [600/1000], Loss: 0.00078689, Reconstruction Loss: 0.00078231, Conformal Loss: 0.00458514, Regularization Loss: 0.02542449
# Epoch [600/1000], Validation Loss: 0.00101332, Reconstruction Loss: 0.00100727, Conformal Loss: 0.00604109, Regularization Loss: 0.00929555
# Epoch [700/1000], Loss: 0.00078057, Reconstruction Loss: 0.00077580, Conformal Loss: 0.00476712, Regularization Loss: 0.02745675
# Epoch [700/1000], Validation Loss: 0.00101044, Reconstruction Loss: 0.00100610, Conformal Loss: 0.00433851, Regularization Loss: 0.00840524
# Epoch [800/1000], Loss: 0.00078296, Reconstruction Loss: 0.00077804, Conformal Loss: 0.00491262, Regularization Loss: 0.03274928
# Epoch [800/1000], Validation Loss: 0.00101014, Reconstruction Loss: 0.00100429, Conformal Loss: 0.00585150, Regularization Loss: 0.00447843
# Epoch [900/1000], Loss: 0.00078332, Reconstruction Loss: 0.00077801, Conformal Loss: 0.00530810, Regularization Loss: 0.02833316
# Epoch [900/1000], Validation Loss: 0.00100969, Reconstruction Loss: 0.00100431, Conformal Loss: 0.00537316, Regularization Loss: 0.01047381
# Epoch [1000/1000], Loss: 0.00078073, Reconstruction Loss: 0.00077568, Conformal Loss: 0.00504808, Regularization Loss: 0.03245590
# Epoch [1000/1000], Validation Loss: 0.00100914, Reconstruction Loss: 0.00100434, Conformal Loss: 0.00480475, Regularization Loss: 0.01173345
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.001_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.001 trained and saved.
# Training model 4/4 with lambda_iso=0.001
# Epoch [100/1000], Loss: 0.00091548, Reconstruction Loss: 0.00090612, Conformal Loss: 0.00936355, Regularization Loss: 0.01628970
# Epoch [100/1000], Validation Loss: 0.00108395, Reconstruction Loss: 0.00107599, Conformal Loss: 0.00795345, Regularization Loss: 0.00437093
# Epoch [200/1000], Loss: 0.00084187, Reconstruction Loss: 0.00083485, Conformal Loss: 0.00701442, Regularization Loss: 0.01392091
# Epoch [200/1000], Validation Loss: 0.00106612, Reconstruction Loss: 0.00105917, Conformal Loss: 0.00694902, Regularization Loss: 0.00802742
# Epoch [300/1000], Loss: 0.00082344, Reconstruction Loss: 0.00081751, Conformal Loss: 0.00592488, Regularization Loss: 0.01000433
# Epoch [300/1000], Validation Loss: 0.00108397, Reconstruction Loss: 0.00107790, Conformal Loss: 0.00606753, Regularization Loss: 0.02438559
# Epoch [400/1000], Loss: 0.00081218, Reconstruction Loss: 0.00080628, Conformal Loss: 0.00590691, Regularization Loss: 0.01607160
# Epoch [400/1000], Validation Loss: 0.00104223, Reconstruction Loss: 0.00103710, Conformal Loss: 0.00513135, Regularization Loss: 0.01176748
# Epoch [500/1000], Loss: 0.00079519, Reconstruction Loss: 0.00079010, Conformal Loss: 0.00509674, Regularization Loss: 0.00778011
# Epoch [500/1000], Validation Loss: 0.00102411, Reconstruction Loss: 0.00101959, Conformal Loss: 0.00451947, Regularization Loss: 0.01140554
# Epoch [600/1000], Loss: 0.00078575, Reconstruction Loss: 0.00078026, Conformal Loss: 0.00549003, Regularization Loss: 0.00591892
# Epoch [600/1000], Validation Loss: 0.00101800, Reconstruction Loss: 0.00101335, Conformal Loss: 0.00464734, Regularization Loss: 0.00476116
# Epoch [700/1000], Loss: 0.00078630, Reconstruction Loss: 0.00078070, Conformal Loss: 0.00560248, Regularization Loss: 0.00499049
# Epoch [700/1000], Validation Loss: 0.00101777, Reconstruction Loss: 0.00101264, Conformal Loss: 0.00512721, Regularization Loss: 0.00064978
# Epoch [800/1000], Loss: 0.00078894, Reconstruction Loss: 0.00078347, Conformal Loss: 0.00547126, Regularization Loss: 0.00905022
# Epoch [800/1000], Validation Loss: 0.00101785, Reconstruction Loss: 0.00101316, Conformal Loss: 0.00469924, Regularization Loss: 0.01094015
# Epoch [900/1000], Loss: 0.00077811, Reconstruction Loss: 0.00077304, Conformal Loss: 0.00506993, Regularization Loss: 0.00524410
# Epoch [900/1000], Validation Loss: 0.00101772, Reconstruction Loss: 0.00101301, Conformal Loss: 0.00470609, Regularization Loss: 0.00529432
# Epoch [1000/1000], Loss: 0.00078314, Reconstruction Loss: 0.00077779, Conformal Loss: 0.00534907, Regularization Loss: 0.00702315
# Epoch [1000/1000], Validation Loss: 0.00101608, Reconstruction Loss: 0.00101236, Conformal Loss: 0.00372707, Regularization Loss: 0.00959072
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.001_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.001 trained and saved.
# Training model 1/4 with lambda_iso=0.004
# Epoch [100/1000], Loss: 0.00089899, Reconstruction Loss: 0.00088296, Conformal Loss: 0.00380269, Regularization Loss: 0.01176422
# Epoch [100/1000], Validation Loss: 0.00122946, Reconstruction Loss: 0.00121018, Conformal Loss: 0.00457229, Regularization Loss: 0.02541712
# Epoch [200/1000], Loss: 0.00087607, Reconstruction Loss: 0.00086251, Conformal Loss: 0.00321592, Regularization Loss: 0.02722546
# Epoch [200/1000], Validation Loss: 0.00113059, Reconstruction Loss: 0.00111494, Conformal Loss: 0.00371095, Regularization Loss: 0.01701101
# Epoch [300/1000], Loss: 0.00082816, Reconstruction Loss: 0.00081635, Conformal Loss: 0.00280062, Regularization Loss: 0.03305656
# Epoch [300/1000], Validation Loss: 0.00105530, Reconstruction Loss: 0.00104181, Conformal Loss: 0.00320014, Regularization Loss: 0.02218432
# Epoch [400/1000], Loss: 0.00082183, Reconstruction Loss: 0.00080897, Conformal Loss: 0.00304888, Regularization Loss: 0.03497795
# Epoch [400/1000], Validation Loss: 0.00104945, Reconstruction Loss: 0.00103868, Conformal Loss: 0.00255352, Regularization Loss: 0.00134764
# Epoch [500/1000], Loss: 0.00080954, Reconstruction Loss: 0.00079719, Conformal Loss: 0.00292874, Regularization Loss: 0.03469760
# Epoch [500/1000], Validation Loss: 0.00104687, Reconstruction Loss: 0.00103517, Conformal Loss: 0.00277378, Regularization Loss: 0.00588276
# Epoch [600/1000], Loss: 0.00080526, Reconstruction Loss: 0.00079406, Conformal Loss: 0.00265506, Regularization Loss: 0.02942912
# Epoch [600/1000], Validation Loss: 0.00104118, Reconstruction Loss: 0.00103155, Conformal Loss: 0.00228488, Regularization Loss: 0.03876886
# Epoch [700/1000], Loss: 0.00079893, Reconstruction Loss: 0.00078827, Conformal Loss: 0.00252704, Regularization Loss: 0.02013952
# Epoch [700/1000], Validation Loss: 0.00104305, Reconstruction Loss: 0.00103162, Conformal Loss: 0.00271100, Regularization Loss: 0.03188661
# Epoch [800/1000], Loss: 0.00079699, Reconstruction Loss: 0.00078660, Conformal Loss: 0.00246266, Regularization Loss: 0.02913702
# Epoch [800/1000], Validation Loss: 0.00104694, Reconstruction Loss: 0.00103127, Conformal Loss: 0.00371729, Regularization Loss: 0.00956158
# Epoch [900/1000], Loss: 0.00079836, Reconstruction Loss: 0.00078713, Conformal Loss: 0.00266343, Regularization Loss: 0.03609243
# Epoch [900/1000], Validation Loss: 0.00104231, Reconstruction Loss: 0.00103057, Conformal Loss: 0.00278373, Regularization Loss: 0.02173757
# Epoch [1000/1000], Loss: 0.00079865, Reconstruction Loss: 0.00078852, Conformal Loss: 0.00240216, Regularization Loss: 0.02197642
# Epoch [1000/1000], Validation Loss: 0.00104229, Reconstruction Loss: 0.00103053, Conformal Loss: 0.00278913, Regularization Loss: 0.02371207
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.004_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.004 trained and saved.
# Training model 2/4 with lambda_iso=0.004
# Epoch [100/1000], Loss: 0.00091626, Reconstruction Loss: 0.00089951, Conformal Loss: 0.00397106, Regularization Loss: 0.00912787
# Epoch [100/1000], Validation Loss: 0.00112819, Reconstruction Loss: 0.00111153, Conformal Loss: 0.00395071, Regularization Loss: 0.01481357
# Epoch [200/1000], Loss: 0.00087565, Reconstruction Loss: 0.00086141, Conformal Loss: 0.00337638, Regularization Loss: 0.00708545
# Epoch [200/1000], Validation Loss: 0.00108404, Reconstruction Loss: 0.00106981, Conformal Loss: 0.00337541, Regularization Loss: 0.01053374
# Epoch [300/1000], Loss: 0.00082390, Reconstruction Loss: 0.00080985, Conformal Loss: 0.00333258, Regularization Loss: 0.01097073
# Epoch [300/1000], Validation Loss: 0.00106736, Reconstruction Loss: 0.00105343, Conformal Loss: 0.00330512, Regularization Loss: 0.00595138
# Epoch [400/1000], Loss: 0.00081700, Reconstruction Loss: 0.00080480, Conformal Loss: 0.00289275, Regularization Loss: 0.00749114
# Epoch [400/1000], Validation Loss: 0.00104693, Reconstruction Loss: 0.00103299, Conformal Loss: 0.00330415, Regularization Loss: 0.00733257
# Epoch [500/1000], Loss: 0.00080411, Reconstruction Loss: 0.00079192, Conformal Loss: 0.00289041, Regularization Loss: 0.00654687
# Epoch [500/1000], Validation Loss: 0.00103975, Reconstruction Loss: 0.00102641, Conformal Loss: 0.00316280, Regularization Loss: 0.01631014
# Epoch [600/1000], Loss: 0.00080822, Reconstruction Loss: 0.00079756, Conformal Loss: 0.00252754, Regularization Loss: 0.01153515
# Epoch [600/1000], Validation Loss: 0.00103995, Reconstruction Loss: 0.00102402, Conformal Loss: 0.00377613, Regularization Loss: 0.00314128
# Epoch [700/1000], Loss: 0.00080754, Reconstruction Loss: 0.00079533, Conformal Loss: 0.00289488, Regularization Loss: 0.01239709
# Epoch [700/1000], Validation Loss: 0.00103770, Reconstruction Loss: 0.00102578, Conformal Loss: 0.00282745, Regularization Loss: 0.00439319
# Epoch [800/1000], Loss: 0.00080465, Reconstruction Loss: 0.00079430, Conformal Loss: 0.00245391, Regularization Loss: 0.00998992
# Epoch [800/1000], Validation Loss: 0.00103835, Reconstruction Loss: 0.00102570, Conformal Loss: 0.00299985, Regularization Loss: 0.01256496
# Epoch [900/1000], Loss: 0.00080586, Reconstruction Loss: 0.00079312, Conformal Loss: 0.00302021, Regularization Loss: 0.00496393
# Epoch [900/1000], Validation Loss: 0.00103923, Reconstruction Loss: 0.00102553, Conformal Loss: 0.00325077, Regularization Loss: 0.00938571
# Epoch [1000/1000], Loss: 0.00080101, Reconstruction Loss: 0.00078876, Conformal Loss: 0.00290365, Regularization Loss: 0.00680752
# Epoch [1000/1000], Validation Loss: 0.00103682, Reconstruction Loss: 0.00102550, Conformal Loss: 0.00268493, Regularization Loss: 0.00136080
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.004_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.004 trained and saved.
# Training model 3/4 with lambda_iso=0.004
# Epoch [100/1000], Loss: 0.00093610, Reconstruction Loss: 0.00091911, Conformal Loss: 0.00402758, Regularization Loss: 0.04397529
# Epoch [100/1000], Validation Loss: 0.00114174, Reconstruction Loss: 0.00112544, Conformal Loss: 0.00386422, Regularization Loss: 0.01733887
# Epoch [200/1000], Loss: 0.00087738, Reconstruction Loss: 0.00086217, Conformal Loss: 0.00360641, Regularization Loss: 0.04716200
# Epoch [200/1000], Validation Loss: 0.00108400, Reconstruction Loss: 0.00106908, Conformal Loss: 0.00353901, Regularization Loss: 0.02631277
# Epoch [300/1000], Loss: 0.00083965, Reconstruction Loss: 0.00082531, Conformal Loss: 0.00340156, Regularization Loss: 0.03174888
# Epoch [300/1000], Validation Loss: 0.00107084, Reconstruction Loss: 0.00105799, Conformal Loss: 0.00304662, Regularization Loss: 0.01954591
# Epoch [400/1000], Loss: 0.00082554, Reconstruction Loss: 0.00081323, Conformal Loss: 0.00292123, Regularization Loss: 0.02210504
# Epoch [400/1000], Validation Loss: 0.00103261, Reconstruction Loss: 0.00102191, Conformal Loss: 0.00253855, Regularization Loss: 0.01865785
# Epoch [500/1000], Loss: 0.00081783, Reconstruction Loss: 0.00080533, Conformal Loss: 0.00296393, Regularization Loss: 0.03250780
# Epoch [500/1000], Validation Loss: 0.00102848, Reconstruction Loss: 0.00101679, Conformal Loss: 0.00277154, Regularization Loss: 0.03616066
# Epoch [600/1000], Loss: 0.00081450, Reconstruction Loss: 0.00079994, Conformal Loss: 0.00345283, Regularization Loss: 0.02188682
# Epoch [600/1000], Validation Loss: 0.00102408, Reconstruction Loss: 0.00101174, Conformal Loss: 0.00292832, Regularization Loss: 0.06120980
# Epoch [700/1000], Loss: 0.00080720, Reconstruction Loss: 0.00079359, Conformal Loss: 0.00322732, Regularization Loss: 0.03581280
# Epoch [700/1000], Validation Loss: 0.00102915, Reconstruction Loss: 0.00101324, Conformal Loss: 0.00377262, Regularization Loss: 0.05710688
# Epoch [800/1000], Loss: 0.00080083, Reconstruction Loss: 0.00078774, Conformal Loss: 0.00310401, Regularization Loss: 0.02302040
# Epoch [800/1000], Validation Loss: 0.00102279, Reconstruction Loss: 0.00101164, Conformal Loss: 0.00264388, Regularization Loss: 0.02935952
# Epoch [900/1000], Loss: 0.00080027, Reconstruction Loss: 0.00078710, Conformal Loss: 0.00312487, Regularization Loss: 0.02779975
# Epoch [900/1000], Validation Loss: 0.00102244, Reconstruction Loss: 0.00101073, Conformal Loss: 0.00277745, Regularization Loss: 0.04798538
# Epoch [1000/1000], Loss: 0.00080061, Reconstruction Loss: 0.00078595, Conformal Loss: 0.00347610, Regularization Loss: 0.02482545
# Epoch [1000/1000], Validation Loss: 0.00102505, Reconstruction Loss: 0.00101132, Conformal Loss: 0.00325531, Regularization Loss: 0.02125269
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.004_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.004 trained and saved.
# Training model 4/4 with lambda_iso=0.004
# Epoch [100/1000], Loss: 0.00090563, Reconstruction Loss: 0.00088868, Conformal Loss: 0.00401822, Regularization Loss: 0.03175946
# Epoch [100/1000], Validation Loss: 0.00109705, Reconstruction Loss: 0.00107851, Conformal Loss: 0.00439674, Regularization Loss: 0.02655634
# Epoch [200/1000], Loss: 0.00084437, Reconstruction Loss: 0.00082948, Conformal Loss: 0.00353056, Regularization Loss: 0.04799810
# Epoch [200/1000], Validation Loss: 0.00107107, Reconstruction Loss: 0.00105573, Conformal Loss: 0.00363643, Regularization Loss: 0.02942962
# Epoch [300/1000], Loss: 0.00082846, Reconstruction Loss: 0.00081391, Conformal Loss: 0.00345235, Regularization Loss: 0.05458632
# Epoch [300/1000], Validation Loss: 0.00106399, Reconstruction Loss: 0.00105069, Conformal Loss: 0.00315374, Regularization Loss: 0.01713240
# Epoch [400/1000], Loss: 0.00080318, Reconstruction Loss: 0.00079060, Conformal Loss: 0.00298391, Regularization Loss: 0.04192452
# Epoch [400/1000], Validation Loss: 0.00105172, Reconstruction Loss: 0.00103880, Conformal Loss: 0.00306530, Regularization Loss: 0.02406478
# Epoch [500/1000], Loss: 0.00080254, Reconstruction Loss: 0.00079035, Conformal Loss: 0.00288926, Regularization Loss: 0.05667567
# Epoch [500/1000], Validation Loss: 0.00105137, Reconstruction Loss: 0.00103877, Conformal Loss: 0.00298651, Regularization Loss: 0.00785005
# Epoch [600/1000], Loss: 0.00079610, Reconstruction Loss: 0.00078242, Conformal Loss: 0.00324597, Regularization Loss: 0.02865244
# Epoch [600/1000], Validation Loss: 0.00104998, Reconstruction Loss: 0.00103622, Conformal Loss: 0.00326244, Regularization Loss: 0.04985017
# Epoch [700/1000], Loss: 0.00079871, Reconstruction Loss: 0.00078624, Conformal Loss: 0.00295671, Regularization Loss: 0.05544449
# Epoch [700/1000], Validation Loss: 0.00105029, Reconstruction Loss: 0.00103687, Conformal Loss: 0.00318403, Regularization Loss: 0.02265346
# Epoch [800/1000], Loss: 0.00079804, Reconstruction Loss: 0.00078551, Conformal Loss: 0.00297147, Regularization Loss: 0.06135859
# Epoch [800/1000], Validation Loss: 0.00105138, Reconstruction Loss: 0.00103659, Conformal Loss: 0.00350845, Regularization Loss: 0.02696347
# Epoch [900/1000], Loss: 0.00080162, Reconstruction Loss: 0.00078853, Conformal Loss: 0.00310593, Regularization Loss: 0.04955183
# Epoch [900/1000], Validation Loss: 0.00105071, Reconstruction Loss: 0.00103629, Conformal Loss: 0.00341923, Regularization Loss: 0.05648224
# Epoch [1000/1000], Loss: 0.00079852, Reconstruction Loss: 0.00078444, Conformal Loss: 0.00333784, Regularization Loss: 0.03267302
# Epoch [1000/1000], Validation Loss: 0.00105151, Reconstruction Loss: 0.00103559, Conformal Loss: 0.00377355, Regularization Loss: 0.05711965
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.004_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.004 trained and saved.
# Training model 1/4 with lambda_iso=0.018
# Epoch [100/1000], Loss: 0.00092491, Reconstruction Loss: 0.00088692, Conformal Loss: 0.00213606, Regularization Loss: 0.01927910
# Epoch [100/1000], Validation Loss: 0.00115048, Reconstruction Loss: 0.00111256, Conformal Loss: 0.00213221, Regularization Loss: 0.03354258
# Epoch [200/1000], Loss: 0.00085874, Reconstruction Loss: 0.00082940, Conformal Loss: 0.00164954, Regularization Loss: 0.02137280
# Epoch [200/1000], Validation Loss: 0.00105780, Reconstruction Loss: 0.00102651, Conformal Loss: 0.00175912, Regularization Loss: 0.00624219
# Epoch [300/1000], Loss: 0.00085020, Reconstruction Loss: 0.00082091, Conformal Loss: 0.00164720, Regularization Loss: 0.02673696
# Epoch [300/1000], Validation Loss: 0.00104538, Reconstruction Loss: 0.00101171, Conformal Loss: 0.00189334, Regularization Loss: 0.03423875
# Epoch [400/1000], Loss: 0.00084174, Reconstruction Loss: 0.00081207, Conformal Loss: 0.00166835, Regularization Loss: 0.02342276
# Epoch [400/1000], Validation Loss: 0.00104365, Reconstruction Loss: 0.00101080, Conformal Loss: 0.00184737, Regularization Loss: 0.00589270
# Epoch [500/1000], Loss: 0.00082912, Reconstruction Loss: 0.00080048, Conformal Loss: 0.00161034, Regularization Loss: 0.03017872
# Epoch [500/1000], Validation Loss: 0.00103833, Reconstruction Loss: 0.00100520, Conformal Loss: 0.00186351, Regularization Loss: 0.02981115
# Epoch [600/1000], Loss: 0.00082066, Reconstruction Loss: 0.00079305, Conformal Loss: 0.00155222, Regularization Loss: 0.04313100
# Epoch [600/1000], Validation Loss: 0.00104351, Reconstruction Loss: 0.00100826, Conformal Loss: 0.00198222, Regularization Loss: 0.02265550
# Epoch [700/1000], Loss: 0.00081685, Reconstruction Loss: 0.00079260, Conformal Loss: 0.00136369, Regularization Loss: 0.02651749
# Epoch [700/1000], Validation Loss: 0.00103030, Reconstruction Loss: 0.00100420, Conformal Loss: 0.00146726, Regularization Loss: 0.03306361
# Epoch [800/1000], Loss: 0.00081365, Reconstruction Loss: 0.00078516, Conformal Loss: 0.00160180, Regularization Loss: 0.03787182
# Epoch [800/1000], Validation Loss: 0.00103648, Reconstruction Loss: 0.00100362, Conformal Loss: 0.00184825, Regularization Loss: 0.00497251
# Epoch [900/1000], Loss: 0.00081365, Reconstruction Loss: 0.00078886, Conformal Loss: 0.00139446, Regularization Loss: 0.03570030
# Epoch [900/1000], Validation Loss: 0.00104349, Reconstruction Loss: 0.00100382, Conformal Loss: 0.00223072, Regularization Loss: 0.01285942
# Epoch [1000/1000], Loss: 0.00082050, Reconstruction Loss: 0.00079255, Conformal Loss: 0.00157220, Regularization Loss: 0.01494486
# Epoch [1000/1000], Validation Loss: 0.00103908, Reconstruction Loss: 0.00100359, Conformal Loss: 0.00199545, Regularization Loss: 0.01801208
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.018_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.018 trained and saved.
# Training model 2/4 with lambda_iso=0.018
# Epoch [100/1000], Loss: 0.00095476, Reconstruction Loss: 0.00090221, Conformal Loss: 0.00295517, Regularization Loss: 0.13368572
# Epoch [100/1000], Validation Loss: 0.00121273, Reconstruction Loss: 0.00115644, Conformal Loss: 0.00316535, Regularization Loss: 0.12567708
# Epoch [200/1000], Loss: 0.00090828, Reconstruction Loss: 0.00086611, Conformal Loss: 0.00237120, Regularization Loss: 0.11236706
# Epoch [200/1000], Validation Loss: 0.00112296, Reconstruction Loss: 0.00107632, Conformal Loss: 0.00262294, Regularization Loss: 0.14441371
# Epoch [300/1000], Loss: 0.00084713, Reconstruction Loss: 0.00080608, Conformal Loss: 0.00230824, Regularization Loss: 0.11450716
# Epoch [300/1000], Validation Loss: 0.00108934, Reconstruction Loss: 0.00104706, Conformal Loss: 0.00237729, Regularization Loss: 0.16495413
# Epoch [400/1000], Loss: 0.00083924, Reconstruction Loss: 0.00079791, Conformal Loss: 0.00232436, Regularization Loss: 0.12501495
# Epoch [400/1000], Validation Loss: 0.00106980, Reconstruction Loss: 0.00102715, Conformal Loss: 0.00239850, Regularization Loss: 0.12761715
# Epoch [500/1000], Loss: 0.00082743, Reconstruction Loss: 0.00078908, Conformal Loss: 0.00215691, Regularization Loss: 0.12004761
# Epoch [500/1000], Validation Loss: 0.00105763, Reconstruction Loss: 0.00101784, Conformal Loss: 0.00223772, Regularization Loss: 0.08721370
# Epoch [600/1000], Loss: 0.00082346, Reconstruction Loss: 0.00078551, Conformal Loss: 0.00213431, Regularization Loss: 0.13773775
# Epoch [600/1000], Validation Loss: 0.00105581, Reconstruction Loss: 0.00101726, Conformal Loss: 0.00216760, Regularization Loss: 0.10815433
# Epoch [700/1000], Loss: 0.00082470, Reconstruction Loss: 0.00079044, Conformal Loss: 0.00192662, Regularization Loss: 0.11947965
# Epoch [700/1000], Validation Loss: 0.00105986, Reconstruction Loss: 0.00101412, Conformal Loss: 0.00257220, Regularization Loss: 0.09612609
# Epoch [800/1000], Loss: 0.00082015, Reconstruction Loss: 0.00078580, Conformal Loss: 0.00193176, Regularization Loss: 0.12714030
# Epoch [800/1000], Validation Loss: 0.00106154, Reconstruction Loss: 0.00101810, Conformal Loss: 0.00244281, Regularization Loss: 0.14394572
# Epoch [900/1000], Loss: 0.00082085, Reconstruction Loss: 0.00078356, Conformal Loss: 0.00209717, Regularization Loss: 0.09909584
# Epoch [900/1000], Validation Loss: 0.00105230, Reconstruction Loss: 0.00101551, Conformal Loss: 0.00206871, Regularization Loss: 0.09935438
# Epoch [1000/1000], Loss: 0.00082159, Reconstruction Loss: 0.00078407, Conformal Loss: 0.00210969, Regularization Loss: 0.10068444
# Epoch [1000/1000], Validation Loss: 0.00105393, Reconstruction Loss: 0.00101588, Conformal Loss: 0.00213958, Regularization Loss: 0.13848019
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.018_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.018 trained and saved.
# Training model 3/4 with lambda_iso=0.018
# Epoch [100/1000], Loss: 0.00096978, Reconstruction Loss: 0.00092492, Conformal Loss: 0.00252252, Regularization Loss: 0.01596607
# Epoch [100/1000], Validation Loss: 0.00116146, Reconstruction Loss: 0.00111768, Conformal Loss: 0.00246207, Regularization Loss: 0.01133323
# Epoch [200/1000], Loss: 0.00088194, Reconstruction Loss: 0.00084601, Conformal Loss: 0.00202079, Regularization Loss: 0.00828272
# Epoch [200/1000], Validation Loss: 0.00110548, Reconstruction Loss: 0.00106836, Conformal Loss: 0.00208740, Regularization Loss: 0.00668136
# Epoch [300/1000], Loss: 0.00084650, Reconstruction Loss: 0.00081361, Conformal Loss: 0.00184941, Regularization Loss: 0.01917622
# Epoch [300/1000], Validation Loss: 0.00109161, Reconstruction Loss: 0.00105758, Conformal Loss: 0.00191362, Regularization Loss: 0.02599712
# Epoch [400/1000], Loss: 0.00082801, Reconstruction Loss: 0.00079896, Conformal Loss: 0.00163320, Regularization Loss: 0.01135475
# Epoch [400/1000], Validation Loss: 0.00105526, Reconstruction Loss: 0.00102449, Conformal Loss: 0.00173044, Regularization Loss: 0.01253293
# Epoch [500/1000], Loss: 0.00081981, Reconstruction Loss: 0.00079063, Conformal Loss: 0.00164071, Regularization Loss: 0.00788752
# Epoch [500/1000], Validation Loss: 0.00105424, Reconstruction Loss: 0.00102215, Conformal Loss: 0.00180430, Regularization Loss: 0.02677540
# Epoch [600/1000], Loss: 0.00081859, Reconstruction Loss: 0.00078927, Conformal Loss: 0.00164837, Regularization Loss: 0.00714586
# Epoch [600/1000], Validation Loss: 0.00104898, Reconstruction Loss: 0.00102050, Conformal Loss: 0.00160138, Regularization Loss: 0.00863101
# Epoch [700/1000], Loss: 0.00082038, Reconstruction Loss: 0.00079271, Conformal Loss: 0.00155589, Regularization Loss: 0.00498981
# Epoch [700/1000], Validation Loss: 0.00104832, Reconstruction Loss: 0.00101837, Conformal Loss: 0.00168461, Regularization Loss: 0.00911865
# Epoch [800/1000], Loss: 0.00081512, Reconstruction Loss: 0.00078439, Conformal Loss: 0.00172770, Regularization Loss: 0.01359986
# Epoch [800/1000], Validation Loss: 0.00104756, Reconstruction Loss: 0.00101882, Conformal Loss: 0.00161646, Regularization Loss: 0.00185228
# Epoch [900/1000], Loss: 0.00080635, Reconstruction Loss: 0.00077916, Conformal Loss: 0.00152902, Regularization Loss: 0.01171087
# Epoch [900/1000], Validation Loss: 0.00105205, Reconstruction Loss: 0.00101948, Conformal Loss: 0.00183148, Regularization Loss: 0.00494652
# Epoch [1000/1000], Loss: 0.00081739, Reconstruction Loss: 0.00078630, Conformal Loss: 0.00174846, Regularization Loss: 0.00968970
# Epoch [1000/1000], Validation Loss: 0.00105113, Reconstruction Loss: 0.00101919, Conformal Loss: 0.00179604, Regularization Loss: 0.00953801
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.018_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.018 trained and saved.
# Training model 4/4 with lambda_iso=0.018
# Epoch [100/1000], Loss: 0.00095607, Reconstruction Loss: 0.00091695, Conformal Loss: 0.00219970, Regularization Loss: 0.01947225
# Epoch [100/1000], Validation Loss: 0.00112523, Reconstruction Loss: 0.00108356, Conformal Loss: 0.00234282, Regularization Loss: 0.00589621
# Epoch [200/1000], Loss: 0.00087917, Reconstruction Loss: 0.00084497, Conformal Loss: 0.00192327, Regularization Loss: 0.01489090
# Epoch [200/1000], Validation Loss: 0.00109768, Reconstruction Loss: 0.00106059, Conformal Loss: 0.00208564, Regularization Loss: 0.00490107
# Epoch [300/1000], Loss: 0.00085919, Reconstruction Loss: 0.00083123, Conformal Loss: 0.00157204, Regularization Loss: 0.01483269
# Epoch [300/1000], Validation Loss: 0.00107664, Reconstruction Loss: 0.00103614, Conformal Loss: 0.00227763, Regularization Loss: 0.02796536
# Epoch [400/1000], Loss: 0.00084891, Reconstruction Loss: 0.00082276, Conformal Loss: 0.00147020, Regularization Loss: 0.01208253
# Epoch [400/1000], Validation Loss: 0.00106478, Reconstruction Loss: 0.00102890, Conformal Loss: 0.00201725, Regularization Loss: 0.00747065
# Epoch [500/1000], Loss: 0.00083394, Reconstruction Loss: 0.00080468, Conformal Loss: 0.00164530, Regularization Loss: 0.01887465
# Epoch [500/1000], Validation Loss: 0.00105414, Reconstruction Loss: 0.00102395, Conformal Loss: 0.00169782, Regularization Loss: 0.01849518
# Epoch [600/1000], Loss: 0.00082258, Reconstruction Loss: 0.00079722, Conformal Loss: 0.00142636, Regularization Loss: 0.01765933
# Epoch [600/1000], Validation Loss: 0.00105342, Reconstruction Loss: 0.00102233, Conformal Loss: 0.00174835, Regularization Loss: 0.02010964
# Epoch [700/1000], Loss: 0.00082184, Reconstruction Loss: 0.00079338, Conformal Loss: 0.00160066, Regularization Loss: 0.01987411
# Epoch [700/1000], Validation Loss: 0.00105319, Reconstruction Loss: 0.00102090, Conformal Loss: 0.00181592, Regularization Loss: 0.00610555
# Epoch [800/1000], Loss: 0.00082199, Reconstruction Loss: 0.00079515, Conformal Loss: 0.00150881, Regularization Loss: 0.01053711
# Epoch [800/1000], Validation Loss: 0.00105451, Reconstruction Loss: 0.00102161, Conformal Loss: 0.00184975, Regularization Loss: 0.01198187
# Epoch [900/1000], Loss: 0.00082861, Reconstruction Loss: 0.00080075, Conformal Loss: 0.00156678, Regularization Loss: 0.01841721
# Epoch [900/1000], Validation Loss: 0.00104940, Reconstruction Loss: 0.00101951, Conformal Loss: 0.00168076, Regularization Loss: 0.00790080
# Epoch [1000/1000], Loss: 0.00082148, Reconstruction Loss: 0.00079552, Conformal Loss: 0.00145973, Regularization Loss: 0.01319813
# Epoch [1000/1000], Validation Loss: 0.00105572, Reconstruction Loss: 0.00101944, Conformal Loss: 0.00204025, Regularization Loss: 0.00449620
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.018_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.018 trained and saved.
# Training model 1/4 with lambda_iso=0.075
# Epoch [100/1000], Loss: 0.00109577, Reconstruction Loss: 0.00096246, Conformal Loss: 0.00177770, Regularization Loss: 0.01410074
# Epoch [100/1000], Validation Loss: 0.00132329, Reconstruction Loss: 0.00120990, Conformal Loss: 0.00151195, Regularization Loss: 0.00396603
# Epoch [200/1000], Loss: 0.00097632, Reconstruction Loss: 0.00087212, Conformal Loss: 0.00138964, Regularization Loss: 0.00721921
# Epoch [200/1000], Validation Loss: 0.00119650, Reconstruction Loss: 0.00109874, Conformal Loss: 0.00130354, Regularization Loss: 0.00123352
# Epoch [300/1000], Loss: 0.00093327, Reconstruction Loss: 0.00083915, Conformal Loss: 0.00125502, Regularization Loss: 0.00591366
# Epoch [300/1000], Validation Loss: 0.00117726, Reconstruction Loss: 0.00107135, Conformal Loss: 0.00141232, Regularization Loss: 0.00415680
# Epoch [400/1000], Loss: 0.00090054, Reconstruction Loss: 0.00082392, Conformal Loss: 0.00102184, Regularization Loss: 0.01716607
# Epoch [400/1000], Validation Loss: 0.00115455, Reconstruction Loss: 0.00105587, Conformal Loss: 0.00131600, Regularization Loss: 0.00760108
# ...
# Epoch [600/1000], Validation Loss: 0.02698583, Reconstruction Loss: 0.00904613, Conformal Loss: 0.00075651, Regularization Loss: 0.50096166
# Epoch [700/1000], Loss: 0.02179148, Reconstruction Loss: 0.00783021, Conformal Loss: 0.00058874, Regularization Loss: 0.50811505
# Epoch [700/1000], Validation Loss: 0.02924390, Reconstruction Loss: 0.00890573, Conformal Loss: 0.00085765, Regularization Loss: 0.49065503
# Epoch [800/1000], Loss: 0.02357988, Reconstruction Loss: 0.00774764, Conformal Loss: 0.00066764, Regularization Loss: 0.49594298
# Epoch [800/1000], Validation Loss: 0.03126310, Reconstruction Loss: 0.00890489, Conformal Loss: 0.00094284, Regularization Loss: 0.48054901
# Epoch [900/1000], Loss: 0.02307442, Reconstruction Loss: 0.00776421, Conformal Loss: 0.00064563, Regularization Loss: 0.48435435
# Epoch [900/1000], Validation Loss: 0.02832745, Reconstruction Loss: 0.00886163, Conformal Loss: 0.00082087, Regularization Loss: 0.46824452
# Epoch [1000/1000], Loss: 0.02810191, Reconstruction Loss: 0.00777150, Conformal Loss: 0.00085733, Regularization Loss: 0.46686086
# Epoch [1000/1000], Validation Loss: 0.02685374, Reconstruction Loss: 0.00887028, Conformal Loss: 0.00075836, Regularization Loss: 0.45419729
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_23.714_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=23.714 trained and saved.
# Training model 4/4 with lambda_iso=23.714
# Epoch [100/1000], Loss: 0.03414914, Reconstruction Loss: 0.00583178, Conformal Loss: 0.00119413, Regularization Loss: 0.49638501
# Epoch [100/1000], Validation Loss: 0.03862749, Reconstruction Loss: 0.00694436, Conformal Loss: 0.00133607, Regularization Loss: 0.51928329
# Epoch [200/1000], Loss: 0.03252430, Reconstruction Loss: 0.00518006, Conformal Loss: 0.00115310, Regularization Loss: 0.50998837
# Epoch [200/1000], Validation Loss: 0.02947603, Reconstruction Loss: 0.00630950, Conformal Loss: 0.00097692, Regularization Loss: 0.52058262
# Epoch [300/1000], Loss: 0.02581666, Reconstruction Loss: 0.00570861, Conformal Loss: 0.00084795, Regularization Loss: 0.50640655
# Epoch [300/1000], Validation Loss: 0.03129725, Reconstruction Loss: 0.00649264, Conformal Loss: 0.00104600, Regularization Loss: 0.49761337
# Epoch [400/1000], Loss: 0.02299992, Reconstruction Loss: 0.00590413, Conformal Loss: 0.00072092, Regularization Loss: 0.53973931
# Epoch [400/1000], Validation Loss: 0.02077906, Reconstruction Loss: 0.00664957, Conformal Loss: 0.00059584, Regularization Loss: 0.54035950
# Epoch [500/1000], Loss: 0.02349917, Reconstruction Loss: 0.00613331, Conformal Loss: 0.00073231, Regularization Loss: 0.54058504
# Epoch [500/1000], Validation Loss: 0.02343935, Reconstruction Loss: 0.00691151, Conformal Loss: 0.00069697, Regularization Loss: 0.54806900
# Epoch [600/1000], Loss: 0.02132536, Reconstruction Loss: 0.00627722, Conformal Loss: 0.00063457, Regularization Loss: 0.54774231
# Epoch [600/1000], Validation Loss: 0.02350592, Reconstruction Loss: 0.00707991, Conformal Loss: 0.00069268, Regularization Loss: 0.53558236
# Epoch [700/1000], Loss: 0.02271224, Reconstruction Loss: 0.00640186, Conformal Loss: 0.00068780, Regularization Loss: 0.55149066
# Epoch [700/1000], Validation Loss: 0.02193840, Reconstruction Loss: 0.00722879, Conformal Loss: 0.00062030, Regularization Loss: 0.53518492
# Epoch [800/1000], Loss: 0.02356169, Reconstruction Loss: 0.00641481, Conformal Loss: 0.00072308, Regularization Loss: 0.55126458
# Epoch [800/1000], Validation Loss: 0.02457652, Reconstruction Loss: 0.00726407, Conformal Loss: 0.00073006, Regularization Loss: 0.55499893
# Epoch [900/1000], Loss: 0.02625617, Reconstruction Loss: 0.00651264, Conformal Loss: 0.00083258, Regularization Loss: 0.55597711
# Epoch [900/1000], Validation Loss: 0.02473944, Reconstruction Loss: 0.00731831, Conformal Loss: 0.00073464, Regularization Loss: 0.54028273
# Epoch [1000/1000], Loss: 0.02493225, Reconstruction Loss: 0.00642384, Conformal Loss: 0.00078049, Regularization Loss: 0.53467178
# Epoch [1000/1000], Validation Loss: 0.02666565, Reconstruction Loss: 0.00733961, Conformal Loss: 0.00081497, Regularization Loss: 0.57299685
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_23.714_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=23.714 trained and saved.
# Training model 1/4 with lambda_iso=100.000
# Epoch [100/1000], Loss: 0.08045060, Reconstruction Loss: 0.01199010, Conformal Loss: 0.00068461, Regularization Loss: 0.40736172
# Epoch [100/1000], Validation Loss: 0.10997415, Reconstruction Loss: 0.01330367, Conformal Loss: 0.00096670, Regularization Loss: 0.41205049
# Epoch [200/1000], Loss: 0.04741101, Reconstruction Loss: 0.01038404, Conformal Loss: 0.00037027, Regularization Loss: 0.43536511
# Epoch [200/1000], Validation Loss: 0.04887221, Reconstruction Loss: 0.01144360, Conformal Loss: 0.00037429, Regularization Loss: 0.45812851
# Epoch [300/1000], Loss: 0.04064631, Reconstruction Loss: 0.01044820, Conformal Loss: 0.00030198, Regularization Loss: 0.46930394
# Epoch [300/1000], Validation Loss: 0.04691409, Reconstruction Loss: 0.01153816, Conformal Loss: 0.00035376, Regularization Loss: 0.44171295
# Epoch [400/1000], Loss: 0.03720110, Reconstruction Loss: 0.00984633, Conformal Loss: 0.00027355, Regularization Loss: 0.47492063
# Epoch [400/1000], Validation Loss: 0.03614083, Reconstruction Loss: 0.01070133, Conformal Loss: 0.00025439, Regularization Loss: 0.45190549
# Epoch [500/1000], Loss: 0.03218715, Reconstruction Loss: 0.00984885, Conformal Loss: 0.00022338, Regularization Loss: 0.46032169
# Epoch [500/1000], Validation Loss: 0.03762773, Reconstruction Loss: 0.01064887, Conformal Loss: 0.00026979, Regularization Loss: 0.49266288
# Epoch [600/1000], Loss: 0.03225847, Reconstruction Loss: 0.00951674, Conformal Loss: 0.00022742, Regularization Loss: 0.47485271
# Epoch [600/1000], Validation Loss: 0.03315981, Reconstruction Loss: 0.01055655, Conformal Loss: 0.00022603, Regularization Loss: 0.47389185
# Epoch [700/1000], Loss: 0.06331263, Reconstruction Loss: 0.00952203, Conformal Loss: 0.00053791, Regularization Loss: 0.47273472
# Epoch [700/1000], Validation Loss: 0.03494205, Reconstruction Loss: 0.01042821, Conformal Loss: 0.00024514, Regularization Loss: 0.43709797
# Epoch [800/1000], Loss: 0.03382689, Reconstruction Loss: 0.00968957, Conformal Loss: 0.00024137, Regularization Loss: 0.46895388
# Epoch [800/1000], Validation Loss: 0.03232281, Reconstruction Loss: 0.01046447, Conformal Loss: 0.00021858, Regularization Loss: 0.49087304
# Epoch [900/1000], Loss: 0.03406885, Reconstruction Loss: 0.00952059, Conformal Loss: 0.00024548, Regularization Loss: 0.46413788
# Epoch [900/1000], Validation Loss: 0.03467708, Reconstruction Loss: 0.01045932, Conformal Loss: 0.00024218, Regularization Loss: 0.48186663
# Epoch [1000/1000], Loss: 0.04893057, Reconstruction Loss: 0.00950784, Conformal Loss: 0.00039423, Regularization Loss: 0.47268519
# Epoch [1000/1000], Validation Loss: 0.03599429, Reconstruction Loss: 0.01048224, Conformal Loss: 0.00025512, Regularization Loss: 0.45219365
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_100.000_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=100.000 trained and saved.
# Training model 2/4 with lambda_iso=100.000
# Epoch [100/1000], Loss: 0.08662324, Reconstruction Loss: 0.01506121, Conformal Loss: 0.00071562, Regularization Loss: 0.45944366
# Epoch [100/1000], Validation Loss: 0.10289159, Reconstruction Loss: 0.01610824, Conformal Loss: 0.00086783, Regularization Loss: 0.48759505
# Epoch [200/1000], Loss: 0.08898511, Reconstruction Loss: 0.00798591, Conformal Loss: 0.00080999, Regularization Loss: 0.43241045
# Epoch [200/1000], Validation Loss: 0.09546477, Reconstruction Loss: 0.00876907, Conformal Loss: 0.00086696, Regularization Loss: 0.45108473
# Epoch [300/1000], Loss: 0.08885678, Reconstruction Loss: 0.00793595, Conformal Loss: 0.00080921, Regularization Loss: 0.40487722
# Epoch [300/1000], Validation Loss: 0.11730564, Reconstruction Loss: 0.00891229, Conformal Loss: 0.00108393, Regularization Loss: 0.42401159
# Epoch [400/1000], Loss: 0.07270377, Reconstruction Loss: 0.00801637, Conformal Loss: 0.00064687, Regularization Loss: 0.38253680
# Epoch [400/1000], Validation Loss: 0.07151292, Reconstruction Loss: 0.00897019, Conformal Loss: 0.00062543, Regularization Loss: 0.41230062
# Epoch [500/1000], Loss: 0.07177519, Reconstruction Loss: 0.00760508, Conformal Loss: 0.00064170, Regularization Loss: 0.36894789
# Epoch [500/1000], Validation Loss: 0.06006928, Reconstruction Loss: 0.00857552, Conformal Loss: 0.00051494, Regularization Loss: 0.37635228
# Epoch [600/1000], Loss: 0.07171615, Reconstruction Loss: 0.00740206, Conformal Loss: 0.00064314, Regularization Loss: 0.39053753
# Epoch [600/1000], Validation Loss: 0.07070467, Reconstruction Loss: 0.00827812, Conformal Loss: 0.00062427, Regularization Loss: 0.40816176
# Epoch [700/1000], Loss: 0.06383307, Reconstruction Loss: 0.00730243, Conformal Loss: 0.00056531, Regularization Loss: 0.40126970
# Epoch [700/1000], Validation Loss: 0.07393783, Reconstruction Loss: 0.00824668, Conformal Loss: 0.00065691, Regularization Loss: 0.39039072
# Epoch [800/1000], Loss: 0.06500155, Reconstruction Loss: 0.00738073, Conformal Loss: 0.00057621, Regularization Loss: 0.41122279
# Epoch [800/1000], Validation Loss: 0.06957322, Reconstruction Loss: 0.00819141, Conformal Loss: 0.00061382, Regularization Loss: 0.41617608
# Epoch [900/1000], Loss: 0.06520541, Reconstruction Loss: 0.00726170, Conformal Loss: 0.00057944, Regularization Loss: 0.41174766
# Epoch [900/1000], Validation Loss: 0.06420453, Reconstruction Loss: 0.00823856, Conformal Loss: 0.00055966, Regularization Loss: 0.43243849
# Epoch [1000/1000], Loss: 0.06775252, Reconstruction Loss: 0.00731565, Conformal Loss: 0.00060437, Regularization Loss: 0.39362541
# Epoch [1000/1000], Validation Loss: 0.06707899, Reconstruction Loss: 0.00821085, Conformal Loss: 0.00058868, Regularization Loss: 0.38205975
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_100.000_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=100.000 trained and saved.
# Training model 3/4 with lambda_iso=100.000
# Epoch [100/1000], Loss: 0.06665637, Reconstruction Loss: 0.02821407, Conformal Loss: 0.00038442, Regularization Loss: 0.48004040
# Epoch [100/1000], Validation Loss: 0.09007938, Reconstruction Loss: 0.03637897, Conformal Loss: 0.00053700, Regularization Loss: 0.44661409
# Epoch [200/1000], Loss: 0.03684873, Reconstruction Loss: 0.01619663, Conformal Loss: 0.00020652, Regularization Loss: 0.38892791
# Epoch [200/1000], Validation Loss: 0.04597810, Reconstruction Loss: 0.02620085, Conformal Loss: 0.00019777, Regularization Loss: 0.40091249
# Epoch [300/1000], Loss: 0.03141013, Reconstruction Loss: 0.01219392, Conformal Loss: 0.00019216, Regularization Loss: 0.38267466
# Epoch [300/1000], Validation Loss: 0.04602936, Reconstruction Loss: 0.02326413, Conformal Loss: 0.00022765, Regularization Loss: 0.37331322
# Epoch [400/1000], Loss: 0.02728474, Reconstruction Loss: 0.01111895, Conformal Loss: 0.00016166, Regularization Loss: 0.38310254
# Epoch [400/1000], Validation Loss: 0.03896033, Reconstruction Loss: 0.02252275, Conformal Loss: 0.00016438, Regularization Loss: 0.39468122
# Epoch [500/1000], Loss: 0.02493874, Reconstruction Loss: 0.01029317, Conformal Loss: 0.00014646, Regularization Loss: 0.37492773
# Epoch [500/1000], Validation Loss: 0.04150559, Reconstruction Loss: 0.02185712, Conformal Loss: 0.00019648, Regularization Loss: 0.34958458
# Epoch [600/1000], Loss: 0.02816259, Reconstruction Loss: 0.00969276, Conformal Loss: 0.00018470, Regularization Loss: 0.39073077
# Epoch [600/1000], Validation Loss: 0.04648606, Reconstruction Loss: 0.02134679, Conformal Loss: 0.00025139, Regularization Loss: 0.38394275
# Epoch [700/1000], Loss: 0.02382232, Reconstruction Loss: 0.00963740, Conformal Loss: 0.00014185, Regularization Loss: 0.37427172
# Epoch [700/1000], Validation Loss: 0.05893531, Reconstruction Loss: 0.02135104, Conformal Loss: 0.00037584, Regularization Loss: 0.38301855
# Epoch [800/1000], Loss: 0.02289633, Reconstruction Loss: 0.00960843, Conformal Loss: 0.00013288, Regularization Loss: 0.42800179
# Epoch [800/1000], Validation Loss: 0.04217342, Reconstruction Loss: 0.02129009, Conformal Loss: 0.00020883, Regularization Loss: 0.36334851
# Epoch [900/1000], Loss: 0.02220659, Reconstruction Loss: 0.00949099, Conformal Loss: 0.00012716, Regularization Loss: 0.39323249
# Epoch [900/1000], Validation Loss: 0.05400210, Reconstruction Loss: 0.02128376, Conformal Loss: 0.00032718, Regularization Loss: 0.36390442
# Epoch [1000/1000], Loss: 0.02445432, Reconstruction Loss: 0.00959203, Conformal Loss: 0.00014862, Regularization Loss: 0.38229695
# Epoch [1000/1000], Validation Loss: 0.04397850, Reconstruction Loss: 0.02126489, Conformal Loss: 0.00022714, Regularization Loss: 0.37988707
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_100.000_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=100.000 trained and saved.
# Training model 4/4 with lambda_iso=100.000
# Epoch [100/1000], Loss: 0.06173331, Reconstruction Loss: 0.01485467, Conformal Loss: 0.00046879, Regularization Loss: 0.43222296
# Epoch [100/1000], Validation Loss: 0.07120042, Reconstruction Loss: 0.01655038, Conformal Loss: 0.00054650, Regularization Loss: 0.44945499
# Epoch [200/1000], Loss: 0.07923140, Reconstruction Loss: 0.01306747, Conformal Loss: 0.00066164, Regularization Loss: 0.41008493
# Epoch [200/1000], Validation Loss: 0.07452123, Reconstruction Loss: 0.01413582, Conformal Loss: 0.00060385, Regularization Loss: 0.41058952
# Epoch [300/1000], Loss: 0.05117264, Reconstruction Loss: 0.01057635, Conformal Loss: 0.00040596, Regularization Loss: 0.41069666
# Epoch [300/1000], Validation Loss: 0.06043709, Reconstruction Loss: 0.01168586, Conformal Loss: 0.00048751, Regularization Loss: 0.44920099
# Epoch [400/1000], Loss: 0.04899846, Reconstruction Loss: 0.01115158, Conformal Loss: 0.00037847, Regularization Loss: 0.42609617
# Epoch [400/1000], Validation Loss: 0.04802167, Reconstruction Loss: 0.01216239, Conformal Loss: 0.00035859, Regularization Loss: 0.42328936
# Epoch [500/1000], Loss: 0.04099755, Reconstruction Loss: 0.01104920, Conformal Loss: 0.00029948, Regularization Loss: 0.39024243
# Epoch [500/1000], Validation Loss: 0.05938082, Reconstruction Loss: 0.01218887, Conformal Loss: 0.00047192, Regularization Loss: 0.38512498
# Epoch [600/1000], Loss: 0.04508670, Reconstruction Loss: 0.01114958, Conformal Loss: 0.00033937, Regularization Loss: 0.39776406
# Epoch [600/1000], Validation Loss: 0.06595768, Reconstruction Loss: 0.01230331, Conformal Loss: 0.00053654, Regularization Loss: 0.40907070
# Epoch [700/1000], Loss: 0.04358945, Reconstruction Loss: 0.01114772, Conformal Loss: 0.00032442, Regularization Loss: 0.44228521
# Epoch [700/1000], Validation Loss: 0.03947587, Reconstruction Loss: 0.01229750, Conformal Loss: 0.00027178, Regularization Loss: 0.45949203
# Epoch [800/1000], Loss: 0.03568697, Reconstruction Loss: 0.01106447, Conformal Loss: 0.00024622, Regularization Loss: 0.44651452
# Epoch [800/1000], Validation Loss: 0.04775831, Reconstruction Loss: 0.01235626, Conformal Loss: 0.00035402, Regularization Loss: 0.41102204
# Epoch [900/1000], Loss: 0.03680955, Reconstruction Loss: 0.01101219, Conformal Loss: 0.00025797, Regularization Loss: 0.43305242
# Epoch [900/1000], Validation Loss: 0.04780378, Reconstruction Loss: 0.01233321, Conformal Loss: 0.00035471, Regularization Loss: 0.44187415
# Epoch [1000/1000], Loss: 0.03335028, Reconstruction Loss: 0.01102223, Conformal Loss: 0.00022328, Regularization Loss: 0.44338477
# Epoch [1000/1000], Validation Loss: 0.03875465, Reconstruction Loss: 0.01237275, Conformal Loss: 0.00026382, Regularization Loss: 0.45003867
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_100.000_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=100.000 trained and saved.

# %%
# from metrics import conformality_jacobian_loss

# reg_metrics = []
# for i, lambda_iso in enumerate(lambda_isos):
#     reg_metric = 0
#     for j in range(num_models):
#         model_path = modelpath(dir_path, lambda_iso, j)
#         model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
#         model.load_state_dict(torch.load(model_path))
        
#         model.eval()
#         z = model.encode(data)
#         reg_metric += conformality_jacobian_loss(model.decode, z)
#     reg_metric /= num_models
#     reg_metrics.append(reg_metric.item())

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.plot(lambda_isos, reg_metrics, label='Conformality Metric')
# plt.ylim(0, 0.02)
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
# save results to csv
results_df = pd.DataFrame({
    'lambda_iso': lambda_isos,
    'reconstruction_error': recon_errors,
    'regularization_error': regularization_errors,
    'conformality_metric': reg_metrics
})
results_df.to_csv(f"{dir_path}/results.csv", index=False)

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    # model.load_state_dict(torch.load(model_path))
    model.load_model_from_checkpoint(model_path)
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=val_labels, s=5)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=val_labels, s=5)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')
# Out:
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.000_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.001_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.004_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.018_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.075_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_0.316_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_1.334_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_5.623_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_23.714_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere_train2/lambda_100.000_model_3.pth

# %%
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decode(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0,:,0,:]

        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)

        # Store the trace value as a label for the point
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]  # Normalize by the number of dimensions

    p = axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    p = axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
statses = []
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    statses.append(evaluate_conformality(model, data)[0])

df = pd.DataFrame(statses, index=lambda_isos)
# styled_df = df.style.highlight_min(color='green').highlight_max(color='coral')

# %%
styled_df = df.style \
    .background_gradient(subset=[
            'reconstruction_error',
            'diagonal_gini',
            'lambda_std',
            'lambda_std_normed',
            'off_diag_mean',
            'off_diag_norm',
            'off_diag_mean_normed',
            'off_diag_norm_normed',
            'jTj_minus_lambdaI_mean',
            'jTj_minus_lambdaI_norm',
            'jTj_minus_lambdaI_mean_normed',
            'jTj_minus_lambdaI_norm_normed',
            'determinant_vs_estimate_std',
            ], cmap='Reds') \
    .background_gradient(subset=[
        'determinant_vs_estimate_mean'
    ], cmap='Greens')\
    .background_gradient(subset=[
        'lambda_mean',
        'latent_std',
        'latent_std_max',
        'latent_std_min',
        'latent_norm',
    ], cmap='Blues')

styled_df
# Out:
# <style type="text/css">
# #T_face2_row0_col0, #T_face2_row1_col0, #T_face2_row2_col0, #T_face2_row3_col0, #T_face2_row4_col0, #T_face2_row8_col4, #T_face2_row9_col1, #T_face2_row9_col3, #T_face2_row9_col6, #T_face2_row9_col7, #T_face2_row9_col8, #T_face2_row9_col9, #T_face2_row9_col10, #T_face2_row9_col11, #T_face2_row9_col12, #T_face2_row9_col13, #T_face2_row9_col15 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_face2_row0_col1, #T_face2_row0_col6, #T_face2_row0_col7, #T_face2_row0_col8, #T_face2_row0_col9, #T_face2_row0_col10, #T_face2_row0_col11, #T_face2_row0_col12, #T_face2_row0_col13, #T_face2_row0_col15, #T_face2_row1_col4, #T_face2_row4_col3, #T_face2_row9_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_face2_row0_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_face2_row0_col3 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_face2_row0_col4 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_face2_row0_col14 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_face2_row0_col21 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_face2_row0_col22 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_face2_row0_col23 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_face2_row0_col24, #T_face2_row3_col21 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_face2_row1_col1 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_face2_row1_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_face2_row1_col3 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_face2_row1_col6, #T_face2_row1_col7 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_face2_row1_col8, #T_face2_row1_col9 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_face2_row1_col10 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_face2_row1_col11 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_face2_row1_col12 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_face2_row1_col13 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_face2_row1_col14 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_face2_row1_col15 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_face2_row1_col21 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_face2_row1_col22 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_face2_row1_col23 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_face2_row1_col24 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_face2_row2_col1, #T_face2_row3_col10, #T_face2_row3_col11 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_face2_row2_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_face2_row2_col3 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_face2_row2_col4 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_face2_row2_col6, #T_face2_row2_col7 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_face2_row2_col8, #T_face2_row2_col9 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_face2_row2_col10 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_face2_row2_col11 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_face2_row2_col12, #T_face2_row2_col13 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_face2_row2_col14 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_face2_row2_col15, #T_face2_row7_col3 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_face2_row2_col21, #T_face2_row2_col22, #T_face2_row4_col23 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_face2_row2_col23 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_face2_row2_col24 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_face2_row3_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_face2_row3_col2 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_face2_row3_col3 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_face2_row3_col4 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_face2_row3_col6, #T_face2_row3_col7 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_face2_row3_col8, #T_face2_row3_col9 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_face2_row3_col12, #T_face2_row3_col13 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_face2_row3_col14 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_face2_row3_col15, #T_face2_row4_col12, #T_face2_row4_col13 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_face2_row3_col22 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_face2_row3_col23 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_face2_row3_col24 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_face2_row4_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_face2_row4_col2, #T_face2_row7_col21, #T_face2_row7_col23, #T_face2_row8_col22, #T_face2_row9_col24 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_face2_row4_col4, #T_face2_row6_col4 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_face2_row4_col6, #T_face2_row4_col7 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_face2_row4_col8, #T_face2_row4_col9 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_face2_row4_col10, #T_face2_row4_col11 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_face2_row4_col14 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_face2_row4_col15, #T_face2_row8_col3 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_face2_row4_col21, #T_face2_row4_col22, #T_face2_row4_col24, #T_face2_row7_col2, #T_face2_row8_col23 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_face2_row5_col0, #T_face2_row8_col15 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_face2_row5_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_face2_row5_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_face2_row5_col3 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_face2_row5_col4 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_face2_row5_col6, #T_face2_row5_col7, #T_face2_row7_col13 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_face2_row5_col8, #T_face2_row5_col9 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_face2_row5_col10, #T_face2_row5_col11, #T_face2_row6_col12, #T_face2_row6_col13, #T_face2_row8_col6, #T_face2_row8_col7 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_face2_row5_col12, #T_face2_row5_col13 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_face2_row5_col14 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_face2_row5_col15, #T_face2_row8_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_face2_row5_col21, #T_face2_row6_col24 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_face2_row5_col22 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_face2_row5_col23 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_face2_row5_col24 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_face2_row6_col0 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_face2_row6_col1, #T_face2_row6_col6, #T_face2_row6_col7 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_face2_row6_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_face2_row6_col3 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_face2_row6_col8, #T_face2_row6_col9 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_face2_row6_col10, #T_face2_row6_col11 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_face2_row6_col14 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_face2_row6_col15, #T_face2_row8_col13 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_face2_row6_col21, #T_face2_row8_col21 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_face2_row6_col22 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_face2_row6_col23 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_face2_row7_col0 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_face2_row7_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_face2_row7_col4 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_face2_row7_col6, #T_face2_row7_col7 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_face2_row7_col8, #T_face2_row7_col9 {
#   background-color: #fdd3c1;
