# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ConformalAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere
from metrics import evaluate_conformality, conformality_jacobian_loss

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
data, labels = make_half_sphere(n_samples=3000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
val_data, val_labels = make_half_sphere(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5)
ax.set_title("Original Data in 3D")
ax.view_init(0, 180, 0)
plt.show()

# %%
# define model parameters
latent_dim = 2
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 128

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)


dir_path = "models/conformal_autoencoder_cosine_comp_halfsphere3"

# %%
lambda_isos = np.logspace(2, 3, 7)
lambda_isos = np.concat([np.zeros(1), lambda_isos])

# %%
from metrics import conformality_cosine_loss

# %%
import os

def modelpath(dir_path, lambda_iso, index):
    os.makedirs(dir_path, exist_ok=True)
    return f"{dir_path}/lambda_{lambda_iso:.3f}_model_{index+1}.pth"

# %%
num_epochs = 1000
# train same model multiple times to average results
num_models = 5

recon_errors = []
regularization_errors = []
reg_metrics = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    reg_metric = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
        model.conformality_loss = conformality_cosine_loss

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = modelpath(dir_path, lambda_iso, j)
        model.save_checkpoint(model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.conformality_loss(model.decoder, encoded_data).item()
        
        reg_metric += conformality_jacobian_loss(model.decoder, encoded_data).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
    reg_metrics.append(reg_metric/num_models)
# Out:
# Training model 1/5 with lambda_iso=0.000
# /home/maxheise/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [100/1000], Loss: 0.00087208, Reconstruction Loss: 0.00087208, Conformal Loss: 0.01648565, Regularization Loss: 0.02465092
# Epoch [100/1000], Validation Loss: 0.00110632, Reconstruction Loss: 0.00110632, Conformal Loss: 0.01910606, Regularization Loss: 0.03938796
# Epoch [200/1000], Loss: 0.00083239, Reconstruction Loss: 0.00083239, Conformal Loss: 0.01849376, Regularization Loss: 0.02490877
# Checkpoint saved to models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_1000.000_model_5.pth at epoch 1001
# Model 5/5 with lambda_iso=1000.000 trained and saved.

# %%
# from metrics import conformality_jacobian_loss

# reg_metrics = []
# for i, lambda_iso in enumerate(lambda_isos):
#     reg_metric = 0
#     for j in range(num_models):
#         model_path = modelpath(dir_path, lambda_iso, j)
#         model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
#         model.load_state_dict(torch.load(model_path))
        
#         model.eval()
#         z = model.encode(data)
#         reg_metric += conformality_jacobian_loss(model.decode, z)
#     reg_metric /= num_models
#     reg_metrics.append(reg_metric.item())

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.plot(lambda_isos, reg_metrics, label='Conformality Metric')
plt.ylim(0, 0.04)
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
# save results to csv
results_df = pd.DataFrame({
    'lambda_iso': lambda_isos,
    'reconstruction_error': recon_errors,
    'regularization_error': regularization_errors,
    'conformality_metric': reg_metrics
})
results_df.to_csv(f"{dir_path}/results.csv", index=False)

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 3)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    # model.load_state_dict(torch.load(model_path))
    model.load_model_from_checkpoint(model_path)
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=val_labels, s=5)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=val_labels, s=5)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')
# Out:
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_0.000_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_100.000_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_146.780_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_215.443_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_316.228_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_464.159_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_681.292_model_4.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_1000.000_model_4.pth

# %%
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decode(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0,:,0,:]

        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)

        # Store the trace value as a label for the point
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]  # Normalize by the number of dimensions

    p = axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    p = axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 5
#       3 model_path = modelpath(dir_path, lambda_iso, 2)
#       4 model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
# ----> 5 model.load_state_dict(torch.load(model_path))
#       7 model.eval()
#       8 with torch.no_grad():
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/nn/modules/module.py:2593, in Module.load_state_dict(self, state_dict, strict, assign)
#    2585         error_msgs.insert(
#    2586             0,
#    2587             "Missing key(s) in state_dict: {}. ".format(
#    2588                 ", ".join(f'"{k}"' for k in missing_keys)
#    2589             ),
#    2590         )
#    2592 if len(error_msgs) > 0:
# -> 2593     raise RuntimeError(
#    2594         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2595             self.__class__.__name__, "\n\t".join(error_msgs)
#    2596         )
#    2597     )
#    2598 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ConformalAutoencoder:
# 	Missing key(s) in state_dict: "encoder.fc.0.weight", "encoder.fc.0.bias", "encoder.fc.2.weight", "encoder.fc.2.bias", "encoder.fc.4.weight", "encoder.fc.4.bias", "decoder.fc.0.weight", "decoder.fc.0.bias", "decoder.fc.2.weight", "decoder.fc.2.bias", "decoder.fc.4.weight", "decoder.fc.4.bias", "model.0.fc.0.weight", "model.0.fc.0.bias", "model.0.fc.2.weight", "model.0.fc.2.bias", "model.0.fc.4.weight", "model.0.fc.4.bias", "model.1.fc.0.weight", "model.1.fc.0.bias", "model.1.fc.2.weight", "model.1.fc.2.bias", "model.1.fc.4.weight", "model.1.fc.4.bias".
# 	Unexpected key(s) in state_dict: "epochs_trained", "model_state_dict", "loss_list", "val_loss_list", "metrics_list", "val_metrics_list".

# %%
statses = []
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    # model.load_state_dict(torch.load(model_path))
    model.load_model_from_checkpoint(model_path)
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    statses.append(evaluate_conformality(model, data))

df = pd.DataFrame(statses, index=lambda_isos)
# styled_df = df.style.highlight_min(color='green').highlight_max(color='coral')
# Out:
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_0.000_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_100.000_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_146.780_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_215.443_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_316.228_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_464.159_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_681.292_model_3.pth
# Model and custom variables loaded from models/conformal_autoencoder_cosine_comp_halfsphere3/lambda_1000.000_model_3.pth

# %%
styled_df = df.style \
    .background_gradient(subset=[
            'reconstruction_error',
            'diagonal_gini',
            'lambda_std',
            'lambda_std_normed',
            'off_diag_mean',
            'off_diag_norm',
            'off_diag_mean_normed',
            'off_diag_norm_normed',
            'jTj_minus_lambdaI_mean',
            'jTj_minus_lambdaI_norm',
            'jTj_minus_lambdaI_mean_normed',
            'jTj_minus_lambdaI_norm_normed',
            'determinant_vs_estimate_std',
            ], cmap='Reds') \
    .background_gradient(subset=[
        'determinant_vs_estimate_mean'
    ], cmap='Greens')\
    .background_gradient(subset=[
        'lambda_mean',
        'latent_std',
        'latent_std_max',
        'latent_std_min',
        'latent_norm',
    ], cmap='Blues')

styled_df
# Out:
# <style type="text/css">
# #T_3f761_row0_col0, #T_3f761_row3_col1, #T_3f761_row3_col3, #T_3f761_row3_col4, #T_3f761_row3_col6, #T_3f761_row3_col7, #T_3f761_row3_col8, #T_3f761_row3_col9, #T_3f761_row3_col10, #T_3f761_row3_col11, #T_3f761_row3_col12, #T_3f761_row3_col13, #T_3f761_row3_col15, #T_3f761_row4_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_3f761_row0_col1, #T_3f761_row0_col3, #T_3f761_row0_col4, #T_3f761_row0_col6, #T_3f761_row0_col7, #T_3f761_row0_col8, #T_3f761_row0_col9, #T_3f761_row0_col10, #T_3f761_row0_col11, #T_3f761_row0_col12, #T_3f761_row0_col13, #T_3f761_row0_col15, #T_3f761_row3_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3f761_row0_col2, #T_3f761_row3_col21, #T_3f761_row3_col23, #T_3f761_row4_col21, #T_3f761_row4_col22, #T_3f761_row4_col24 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3f761_row0_col14 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3f761_row0_col21, #T_3f761_row0_col22, #T_3f761_row0_col23, #T_3f761_row0_col24, #T_3f761_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3f761_row1_col0 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_3f761_row1_col1 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_3f761_row1_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_3f761_row1_col3 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_3f761_row1_col4 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_3f761_row1_col6, #T_3f761_row1_col7, #T_3f761_row7_col3 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_3f761_row1_col8, #T_3f761_row1_col9 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_3f761_row1_col10, #T_3f761_row1_col11 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_3f761_row1_col12 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_3f761_row1_col13, #T_3f761_row7_col12 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_3f761_row1_col14 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_3f761_row1_col15 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_3f761_row1_col21 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_3f761_row1_col22 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_3f761_row1_col23 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_3f761_row1_col24 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_3f761_row2_col0 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_3f761_row2_col1, #T_3f761_row4_col1 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_3f761_row2_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_3f761_row2_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_3f761_row2_col4, #T_3f761_row2_col15, #T_3f761_row7_col15 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_3f761_row2_col6, #T_3f761_row2_col7 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_3f761_row2_col8, #T_3f761_row2_col9, #T_3f761_row4_col8, #T_3f761_row4_col9, #T_3f761_row6_col15 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_3f761_row2_col10 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_3f761_row2_col11 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_3f761_row2_col12, #T_3f761_row2_col13, #T_3f761_row4_col12 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_3f761_row2_col14 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_3f761_row2_col21 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_3f761_row2_col22 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_3f761_row2_col23 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_3f761_row2_col24 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_3f761_row3_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_3f761_row3_col14 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3f761_row3_col22 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_3f761_row3_col24 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_3f761_row4_col0 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_3f761_row4_col4, #T_3f761_row5_col10, #T_3f761_row5_col11 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_3f761_row4_col6, #T_3f761_row4_col7 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_3f761_row4_col10, #T_3f761_row4_col11 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_3f761_row4_col13, #T_3f761_row5_col3 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_3f761_row4_col14, #T_3f761_row5_col14 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_3f761_row4_col15 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_3f761_row4_col23 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_3f761_row5_col0 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_3f761_row5_col1, #T_3f761_row6_col10, #T_3f761_row6_col11 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_3f761_row5_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_3f761_row5_col4 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_3f761_row5_col6, #T_3f761_row5_col7, #T_3f761_row7_col6, #T_3f761_row7_col7 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_3f761_row5_col8, #T_3f761_row5_col9, #T_3f761_row5_col13 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_3f761_row5_col12 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_3f761_row5_col15 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_3f761_row5_col21 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_3f761_row5_col22 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_3f761_row5_col23 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_3f761_row5_col24 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_3f761_row6_col0 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_3f761_row6_col1 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_3f761_row6_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_3f761_row6_col3 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_3f761_row6_col4 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_3f761_row6_col6, #T_3f761_row6_col7 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_3f761_row6_col8, #T_3f761_row6_col9 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_3f761_row6_col12 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_3f761_row6_col13, #T_3f761_row7_col13 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_3f761_row6_col14 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_3f761_row6_col21 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_3f761_row6_col22 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_3f761_row6_col23 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_3f761_row6_col24 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3f761_row7_col0 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_3f761_row7_col1 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_3f761_row7_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3f761_row7_col4 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_3f761_row7_col8, #T_3f761_row7_col9 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_3f761_row7_col10, #T_3f761_row7_col11 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_3f761_row7_col14 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_3f761_row7_col21 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_3f761_row7_col22 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_3f761_row7_col23 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_3f761_row7_col24 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# </style>
# <table id="T_3f761">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f761_level0_col0" class="col_heading level0 col0" >reconstruction_error</th>
#       <th id="T_3f761_level0_col1" class="col_heading level0 col1" >diagonal_gini</th>
#       <th id="T_3f761_level0_col2" class="col_heading level0 col2" >lambda_mean</th>
#       <th id="T_3f761_level0_col3" class="col_heading level0 col3" >lambda_std</th>
#       <th id="T_3f761_level0_col4" class="col_heading level0 col4" >lambda_std_normed</th>
#       <th id="T_3f761_level0_col5" class="col_heading level0 col5" >lamb
