# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ScaledIsometricAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere
from metrics import evaluate_conformality, scaled_isometry_jacobian_loss

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
# Generate S-curve dataset
data, labels = make_s_curve(n_samples=3000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
labels = torch.tensor(labels, dtype=torch.float32)

val_data, val_labels = make_s_curve(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)
val_labels = torch.tensor(val_labels, dtype=torch.float32)

# %%
# Visualize the S-curve data
fig = plt.figure(figsize=(12, 5))

# 3D view
ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5, cmap='viridis')
ax1.set_title("S-curve Data in 3D")
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Color by intrinsic coordinate
ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5, cmap='plasma')
ax2.set_title("S-curve colored by intrinsic coordinate")
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.tight_layout()
plt.show()

# %%
# Define model parameters
latent_dim = 2
input_dim = data.shape[1]  # 3 for S-curve
output_dim = data.shape[1]
batch_size = 128

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

dir_path = "models/isometric_scaled_autoencoder_comp_scurve"

# %%
# Lambda values for comparison
lambda_isos = np.logspace(-3, 2, 9)
lambda_isos = np.concatenate([np.zeros(1), lambda_isos])

# %%
# Using scaled isometry loss (no specific import needed, it's in the autoencoder)

# %%
import os

def modelpath(dir_path, lambda_iso, index):
    os.makedirs(dir_path, exist_ok=True)
    return f"{dir_path}/lambda_{lambda_iso:.3f}_model_{index+1}.pth"

# %%
num_epochs = 1000
# Train same model multiple times to average results
num_models = 4

recon_errors = []
regularization_errors = []
reg_metrics = []

for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    reg_metric = 0
    
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ScaledIsometricAutoencoder(encoder, decoder, lambda_iso=lambda_iso).to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=False, log_every=200)

        # Save the model
        model_path = modelpath(dir_path, lambda_iso, j)
        model.save_checkpoint(model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # Evaluation
        model.eval()
        with torch.no_grad():
            encoded_data = model.encode(val_data)
            reconstruction = model.decode(encoded_data)
            
            recon_error += nn.MSELoss()(reconstruction, val_data).item()
            regularization += model.scaled_isometry_loss(model.decoder, encoded_data).item()
            reg_metric += scaled_isometry_jacobian_loss(model.decoder, encoded_data).item()
    
    recon_errors.append(recon_error / num_models)
    regularization_errors.append(regularization / num_models)
    reg_metrics.append(reg_metric / num_models)
    
    print(f"Lambda {lambda_iso:.3f} completed - Recon: {recon_errors[-1]:.6f}, Reg: {regularization_errors[-1]:.6f}")
# Out:
# Training model 1/4 with lambda_iso=0.000
# /home/maxheise/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.000 trained and saved.
# Training model 2/4 with lambda_iso=0.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.000 trained and saved.
# Training model 3/4 with lambda_iso=0.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.000 trained and saved.
# Training model 4/4 with lambda_iso=0.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.000 trained and saved.
# Lambda 0.000 completed - Recon: 0.001355, Reg: 0.971292
# Training model 1/4 with lambda_iso=0.001
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.001 trained and saved.
# Training model 2/4 with lambda_iso=0.001
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.001 trained and saved.
# Training model 3/4 with lambda_iso=0.001
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.001 trained and saved.
# Training model 4/4 with lambda_iso=0.001
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.001 trained and saved.
# Lambda 0.001 completed - Recon: 0.001363, Reg: 0.634133
# Training model 1/4 with lambda_iso=0.004
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.004 trained and saved.
# Training model 2/4 with lambda_iso=0.004
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.004 trained and saved.
# Training model 3/4 with lambda_iso=0.004
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.004 trained and saved.
# Training model 4/4 with lambda_iso=0.004
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.004 trained and saved.
# Lambda 0.004 completed - Recon: 0.001432, Reg: 0.592712
# Training model 1/4 with lambda_iso=0.018
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.018 trained and saved.
# Training model 2/4 with lambda_iso=0.018
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.018 trained and saved.
# Training model 3/4 with lambda_iso=0.018
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.018 trained and saved.
# Training model 4/4 with lambda_iso=0.018
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.018 trained and saved.
# Lambda 0.018 completed - Recon: 0.002134, Reg: 0.583368
# Training model 1/4 with lambda_iso=0.075
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.075 trained and saved.
# Training model 2/4 with lambda_iso=0.075
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.075 trained and saved.
# Training model 3/4 with lambda_iso=0.075
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.075 trained and saved.
# Training model 4/4 with lambda_iso=0.075
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.075 trained and saved.
# Lambda 0.075 completed - Recon: 0.002815, Reg: 0.517088
# Training model 1/4 with lambda_iso=0.316
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=0.316 trained and saved.
# Training model 2/4 with lambda_iso=0.316
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=0.316 trained and saved.
# Training model 3/4 with lambda_iso=0.316
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=0.316 trained and saved.
# Training model 4/4 with lambda_iso=0.316
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=0.316 trained and saved.
# Lambda 0.316 completed - Recon: 0.003436, Reg: 0.501052
# Training model 1/4 with lambda_iso=1.334
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=1.334 trained and saved.
# Training model 2/4 with lambda_iso=1.334
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=1.334 trained and saved.
# Training model 3/4 with lambda_iso=1.334
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=1.334 trained and saved.
# Training model 4/4 with lambda_iso=1.334
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=1.334 trained and saved.
# Lambda 1.334 completed - Recon: 0.006109, Reg: 0.498856
# Training model 1/4 with lambda_iso=5.623
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=5.623 trained and saved.
# Training model 2/4 with lambda_iso=5.623
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=5.623 trained and saved.
# Training model 3/4 with lambda_iso=5.623
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=5.623 trained and saved.
# Training model 4/4 with lambda_iso=5.623
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=5.623 trained and saved.
# Lambda 5.623 completed - Recon: 0.008456, Reg: 0.497475
# Training model 1/4 with lambda_iso=23.714
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=23.714 trained and saved.
# Training model 2/4 with lambda_iso=23.714
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=23.714 trained and saved.
# Training model 3/4 with lambda_iso=23.714
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=23.714 trained and saved.
# Training model 4/4 with lambda_iso=23.714
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=23.714 trained and saved.
# Lambda 23.714 completed - Recon: 0.032212, Reg: 0.499684
# Training model 1/4 with lambda_iso=100.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_1.pth at epoch 1001
# Model 1/4 with lambda_iso=100.000 trained and saved.
# Training model 2/4 with lambda_iso=100.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_2.pth at epoch 1001
# Model 2/4 with lambda_iso=100.000 trained and saved.
# Training model 3/4 with lambda_iso=100.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_3.pth at epoch 1001
# Model 3/4 with lambda_iso=100.000 trained and saved.
# Training model 4/4 with lambda_iso=100.000
# Checkpoint saved to models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_4.pth at epoch 1001
# Model 4/4 with lambda_iso=100.000 trained and saved.
# Lambda 100.000 completed - Recon: 0.051473, Reg: 0.506702

# %%
# Plot error curves
plt.figure(figsize=(10, 6))
plt.plot(lambda_isos, recon_errors, 'o-', label='Reconstruction Error', linewidth=2)
plt.plot(lambda_isos, regularization_errors, 's-', label='Scaled Isometry Error', linewidth=2)
plt.plot(lambda_isos, reg_metrics, '^-', label='Scaled Isometry Metric', linewidth=2)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Lambda (Scaled Isometry Weight)')
plt.ylabel('Error (log scale)')
plt.title('S-curve: Scaled Isometric Autoencoder - Reconstruction and Isometry Errors vs Lambda')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Save results to CSV
results_df = pd.DataFrame({
    'lambda_iso': lambda_isos,
    'reconstruction_error': recon_errors,
    'regularization_error': regularization_errors,
    'scaled_isometry_metric': reg_metrics
})
results_df.to_csv(f"{dir_path}/results.csv", index=False)
print("Results saved to CSV")
# Out:
# Results saved to CSV

# %%
# Visualize latent representations and reconstructions
fig, axs = plt.subplots(2, min(10, len(lambda_isos)), figsize=(4*min(10, len(lambda_isos)), 8))
if len(lambda_isos) == 1:
    axs = axs.reshape(2, 1)

for i, lambda_iso in enumerate(lambda_isos[:10]):  # Limit to 10 for visibility
    # Load a trained model
    model_path = modelpath(dir_path, lambda_iso, 3)  # Use first model
    encoder = Encoder(input_dim, latent_dim).to(device)
    decoder = Decoder(latent_dim, output_dim).to(device)
    model = ScaledIsometricAutoencoder(encoder, decoder, lambda_iso=lambda_iso).to(device)
    model.load_model_from_checkpoint(model_path)
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    # Plot latent space (2D)
    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), 
                     c=val_labels, s=5, cmap='viridis')
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    
    # Create 3D subplot for reconstruction
    ax_3d = fig.add_subplot(2, min(10, len(lambda_isos)), min(10, len(lambda_isos)) + i + 1, projection='3d')
    ax_3d.scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), 
                 c=val_labels, s=5, cmap='viridis')
    ax_3d.set_title(f'Reconstruction (λ={lambda_iso:.3f})')

plt.tight_layout()
plt.show()
# Out:
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_4.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_4.pth

# %%
# Analyze scaled isometry with trace visualization
fig, axs = plt.subplots(2, min(10, len(lambda_isos)), figsize=(4*min(10, len(lambda_isos)), 8))
if len(lambda_isos) == 1:
    axs = axs.reshape(2, 1)

for i, lambda_iso in enumerate(lambda_isos[:10]):  # Limit to 10 for visibility
    # Load model
    model_path = modelpath(dir_path, lambda_iso, 0)
    encoder = Encoder(input_dim, latent_dim).to(device)
    decoder = Decoder(latent_dim, output_dim).to(device)
    model = ScaledIsometricAutoencoder(encoder, decoder, lambda_iso=lambda_iso).to(device)
    model.load_model_from_checkpoint(model_path)
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    # Compute scaled isometry traces
    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data[:100]):  # Limit for computational efficiency
        z = z.unsqueeze(0)  # Add batch dimension
        
        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0, :, 0, :]
        
        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)
        
        # Store the normalized trace value
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]

    # Plot latent space colored by scaled isometry
    scatter = axs[0, i].scatter(encoded_data[:100, 0].cpu(), encoded_data[:100, 1].cpu(), 
                               c=trace_vals[:100], s=20, cmap='coolwarm')
    axs[0, i].set_title(f'Latent Space - Scaled Isometry\n(λ={lambda_iso:.3f})')
    
    # Plot reconstruction colored by scaled isometry
    ax_3d = fig.add_subplot(2, min(10, len(lambda_isos)), min(10, len(lambda_isos)) + i + 1, projection='3d')
    scatter_3d = ax_3d.scatter(reconstruction[:100, 0].cpu(), reconstruction[:100, 1].cpu(), 
                              reconstruction[:100, 2].cpu(), c=trace_vals[:100], s=20, cmap='coolwarm')
    ax_3d.set_title(f'Reconstruction - Scaled Isometry\n(λ={lambda_iso:.3f})')

plt.tight_layout()
plt.show()
# Out:
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_1.pth
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_1.pth

# %%
# Comprehensive conformality evaluation (to compare with conformal autoencoders)
statses = []
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 0)
    encoder = Encoder(input_dim, latent_dim).to(device)
    decoder = Decoder(latent_dim, output_dim).to(device)
    model = ScaledIsometricAutoencoder(encoder, decoder, lambda_iso=lambda_iso).to(device)
    model.load_model_from_checkpoint(model_path)
    
    model.eval()
    stats = evaluate_conformality(model, val_data, double_precision=True)
    statses.append(stats)
    print(f"Lambda {lambda_iso:.3f} - Lambda mean: {stats['lambda_mean']:.4f}, std: {stats['lambda_std']:.4f}")

# Create comprehensive results DataFrame
df = pd.DataFrame(statses, index=[f"{λ:.3f}" for λ in lambda_isos])
print("\nConformality Analysis Complete (for scaled isometric autoencoder)")
# Out:
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.000_model_1.pth
# Lambda 0.000 - Lambda mean: 0.9452, std: 0.3364
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.001_model_1.pth
# Lambda 0.001 - Lambda mean: 1.7306, std: 0.4659
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.004_model_1.pth
# Lambda 0.004 - Lambda mean: 1.6784, std: 0.4075
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.018_model_1.pth
# Lambda 0.018 - Lambda mean: 1.7372, std: 0.3779
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.075_model_1.pth
# Lambda 0.075 - Lambda mean: 1.7713, std: 0.2500
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_0.316_model_1.pth
# Lambda 0.316 - Lambda mean: 2.2510, std: 0.1149
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_1.334_model_1.pth
# Lambda 1.334 - Lambda mean: 1.8308, std: 0.0305
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_5.623_model_1.pth
# Lambda 5.623 - Lambda mean: 0.3945, std: 0.0165
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_23.714_model_1.pth
# Lambda 23.714 - Lambda mean: 0.7493, std: 0.0090
# Model and custom variables loaded from models/isometric_scaled_autoencoder_comp_scurve/lambda_100.000_model_1.pth
# Lambda 100.000 - Lambda mean: 0.4909, std: 0.0036
#
# Conformality Analysis Complete (for scaled isometric autoencoder)

# %%
# Style the results DataFrame for better visualization
styled_df = df.style \
    .background_gradient(subset=[
            'reconstruction_error',
            'diagonal_gini',
            'lambda_std',
            'lambda_std_normed',
            'off_diag_mean',
            'off_diag_norm',
            'off_diag_mean_normed',
            'off_diag_norm_normed',
            'jTj_minus_lambdaI_mean',
            'jTj_minus_lambdaI_norm',
            'jTj_minus_lambdaI_mean_normed',
            'jTj_minus_lambdaI_norm_normed',
            'determinant_vs_estimate_std',
            ], cmap='Reds') \
    .background_gradient(subset=[
        'determinant_vs_estimate_mean'
    ], cmap='Greens') \
    .background_gradient(subset=[
        'lambda_mean',
        'latent_std',
        'latent_std_max',
        'latent_std_min',
        'latent_norm',
    ], cmap='Blues') \
    .format(precision=4)

styled_df
# Out:
# <style type="text/css">
# #T_5adf5_row0_col0, #T_5adf5_row8_col15, #T_5adf5_row9_col1, #T_5adf5_row9_col3, #T_5adf5_row9_col4, #T_5adf5_row9_col6, #T_5adf5_row9_col7, #T_5adf5_row9_col8, #T_5adf5_row9_col9, #T_5adf5_row9_col10, #T_5adf5_row9_col11, #T_5adf5_row9_col12, #T_5adf5_row9_col13, #T_5adf5_row9_col15 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_5adf5_row0_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col2, #T_5adf5_row4_col23 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_5adf5_row0_col3 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col4, #T_5adf5_row0_col8, #T_5adf5_row0_col9, #T_5adf5_row0_col12, #T_5adf5_row0_col13, #T_5adf5_row1_col1, #T_5adf5_row1_col3, #T_5adf5_row1_col6, #T_5adf5_row1_col7, #T_5adf5_row1_col10, #T_5adf5_row1_col11, #T_5adf5_row1_col15, #T_5adf5_row8_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col6, #T_5adf5_row0_col7, #T_5adf5_row1_col8, #T_5adf5_row1_col9, #T_5adf5_row2_col11 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col10 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col11 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col14 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_5adf5_row0_col15 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col21, #T_5adf5_row8_col24 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col22 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_5adf5_row0_col23 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_5adf5_row0_col24, #T_5adf5_row5_col2, #T_5adf5_row7_col21, #T_5adf5_row7_col23, #T_5adf5_row9_col21, #T_5adf5_row9_col22 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5adf5_row1_col0, #T_5adf5_row2_col0, #T_5adf5_row6_col3 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_5adf5_row1_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_5adf5_row1_col4 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_5adf5_row1_col12, #T_5adf5_row2_col1 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_5adf5_row1_col13 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_5adf5_row1_col14 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_5adf5_row1_col21 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_5adf5_row1_col22 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_5adf5_row1_col23, #T_5adf5_row2_col23 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_5adf5_row1_col24, #T_5adf5_row6_col24 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_5adf5_row2_col2 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col3 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col4 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col6, #T_5adf5_row2_col7 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col8, #T_5adf5_row2_col9 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col10 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col12 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col13 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col14 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_5adf5_row2_col15, #T_5adf5_row9_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_5adf5_row2_col21 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_5adf5_row2_col22, #T_5adf5_row3_col21 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_5adf5_row2_col24 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_5adf5_row3_col0, #T_5adf5_row7_col8, #T_5adf5_row7_col9 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_5adf5_row3_col1 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col3 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col4 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col6, #T_5adf5_row3_col7 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col8, #T_5adf5_row3_col9 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col10 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col11 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col12 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col13 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col14 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col15 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_5adf5_row3_col22, #T_5adf5_row3_col24, #T_5adf5_row5_col21, #T_5adf5_row5_col23, #T_5adf5_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5adf5_row3_col23 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_5adf5_row4_col0, #T_5adf5_row7_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_5adf5_row4_col1 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_5adf5_row4_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_5adf5_row4_col3 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_5adf5_row4_col4 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_5adf5_row4_col6, #T_5adf5_row4_col7 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_5adf5_row4_col8, #T_5adf5_row4_col9 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_5adf5_row4_col10, #T_5adf5_row4_col11 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_5adf5_row4_col12 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_5adf5_row4_col13 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_5adf5_row4_col14 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_5adf5_row4_col15 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_5adf5_row4_col21, #T_5adf5_row8_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_5adf5_row4_col22 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_5adf5_row4_col24 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_5adf5_row5_col0 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_5adf5_row5_col1, #T_5adf5_row5_col4 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_5adf5_row5_col3 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_5adf5_row5_col6, #T_5adf5_row5_col7 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_5adf5_row5_col8, #T_5adf5_row5_col9, #T_5adf5_row7_col13 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_5adf5_row5_col10, #T_5adf5_row5_col11 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_5adf5_row5_col12 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_5adf5_row5_col13, #T_5adf5_row7_col4 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_5adf5_row5_col14 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_5adf5_row5_col15 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_5adf5_row5_col22 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_5adf5_row5_col24 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_5adf5_row6_col0, #T_5adf5_row8_col6, #T_5adf5_row8_col7, #T_5adf5_row8_col8, #T_5adf5_row8_col9, #T_5adf5_row8_col10, #T_5adf5_row8_col11, #T_5adf5_row8_col12, #T_5adf5_row8_col13 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_5adf5_row6_col1, #T_5adf5_row6_col8, #T_5adf5_row6_col9, #T_5adf5_row6_col12, #T_5adf5_row6_col13, #T_5adf5_row6_col15, #T_5adf5_row8_col1, #T_5adf5_row8_col3 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_5adf5_row6_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_5adf5_row6_col4 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_5adf5_row6_col6, #T_5adf5_row6_col7, #T_5adf5_row6_col10, #T_5adf5_row6_col11, #T_5adf5_row7_col15 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_5adf5_row6_col14, #T_5adf5_row8_col14, #T_5adf5_row9_col14 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5adf5_row6_col21 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_5adf5_row6_col22 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_5adf5_row6_col23 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_5adf5_row7_col0 {
#   back
