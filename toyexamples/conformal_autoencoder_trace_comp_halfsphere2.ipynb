# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import make_moons, make_s_curve

from Autoencoders import ConformalAutoencoder
from helper import load_optimizer_and_scheduler, save_optimizer_and_scheduler
from data import make_half_sphere
from metrics import evaluate_conformality, conformality_jacobian_loss

random_state = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(Encoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )
    
    def forward(self, x):
        return self.fc(x)

class Decoder(nn.Module):
    def __init__(self, latent_dim, output_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )
    
    def forward(self, z):
        return self.fc(z)

# %%
data, labels = make_half_sphere(n_samples=3000, noise=0.05, random_state=random_state)
data = torch.tensor(data, dtype=torch.float32).to(device)
val_data, val_labels = make_half_sphere(n_samples=1000, noise=0.05, random_state=random_state+1)
val_data = torch.tensor(val_data, dtype=torch.float32).to(device)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0].cpu(), data[:, 1].cpu(), data[:, 2].cpu(), c=labels, s=5)
ax.set_title("Original Data in 3D")
ax.view_init(0, 180, 0)
plt.show()

# %%
# define model parameters
latent_dim = 2
input_dim = data.shape[1]
output_dim = data.shape[1]
batch_size = 128

train_dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)


dir_path = "models/conformal_autoencoder_trace_comp_halfsphere2"

# %%
lambda_isos = np.logspace(-2, 3, 9)
lambda_isos = np.concat([np.zeros(1), lambda_isos])

# %%
from metrics import conformality_trace_loss

# %%
import os

def modelpath(dir_path, lambda_iso, index):
    os.makedirs(dir_path, exist_ok=True)
    return f"{dir_path}/lambda_{lambda_iso:.3f}_model_{index+1}.pth"

# %%
num_epochs = 1000
# train same model multiple times to average results
num_models = 4

recon_errors = []
regularization_errors = []
reg_metrics = []


for i, lambda_iso in enumerate(lambda_isos):
    recon_error = 0
    regularization = 0
    reg_metric = 0
    for j in range(num_models):
        print(f"Training model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f}")
        
        encoder = Encoder(input_dim, latent_dim).to(device)
        decoder = Decoder(latent_dim, output_dim).to(device)
        model = ConformalAutoencoder(encoder, decoder, lambda_conf=lambda_iso).to(device)
        model.conformality_loss = conformality_trace_loss

        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)

        # Train the model
        model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
                          optimizer=optimizer, scheduler=scheduler, verbose=True)

        # Save the model and optimizer state
        model_path = modelpath(dir_path, lambda_iso, j)
        model.save_checkpoint(model_path)
        print(f"Model {j+1}/{num_models} with lambda_iso={lambda_iso:.3f} trained and saved.")

        # evaluation
        model.eval()
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)
        
        recon_error += nn.MSELoss()(reconstruction, val_data).item()

        regularization += model.conformality_loss(model.decoder, encoded_data).item()

        reg_metric += conformality_jacobian_loss(model.decoder, encoded_data).item()
    
    recon_errors.append(recon_error/ num_models)
    regularization_errors.append(regularization/num_models)
    reg_metrics.append(reg_metric/num_models)
# Out:
# Training model 1/4 with lambda_iso=0.000
# /home/maxheise/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:181.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 26
#      23 scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
#      25 # Train the model
# ---> 26 model.train_model(train_dataloader, val_dataloader, batch_size=batch_size, epochs=num_epochs,
#      27                   optimizer=optimizer, scheduler=scheduler, verbose=True)
#      29 # Save the model and optimizer state
#      30 model_path = modelpath(dir_path, lambda_iso, j)
#
# File ~/Documents/HCI/ConformalAutoencoder/Autoencoders.py:119, in Autoencoder.train_model(self, train_dataloader, val_dataloader, epochs, batch_size, learning_rate, optimizer, scheduler, optimizer_kwargs, scheduler_kwargs, log_every, val_every, verbose)
#     117     # Backward pass and optimization
#     118     optimizer.zero_grad()
# --> 119     loss.backward()
#     120     optimizer.step()
#     122 batch_loss = self.get_batch_loss(loss_list)
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/anaconda3/envs/ML/lib/python3.13/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
plt.plot(lambda_isos, recon_errors, label='Reconstruction Error')
plt.plot(lambda_isos, regularization_errors, label='Regularization Error')
plt.ylim(0, 0.02)
plt.xscale('log')
plt.xlabel('Lambda (log scale)')
plt.ylabel('Error')
plt.title('Reconstruction and Regularization Errors vs Lambda')
plt.legend()
plt.show()

# %%
# save results to csv
results_df = pd.DataFrame({
    'lambda_iso': lambda_isos,
    'reconstruction_error': recon_errors,
    'regularization_error': regularization_errors,
    'conformality_metric': reg_metrics
})
results_df.to_csv(f"{dir_path}/results.csv", index=False)

# %%
# plot samples and latent space at different lambdas
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=val_labels, s=5)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=val_labels, s=5)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
fig, axs = plt.subplots(2, 10, figsize=(40, 8), subplot_kw=dict(projection='3d'))
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    trace_vals = np.zeros_like(encoded_data[:, 0].cpu())
    for j, z in enumerate(encoded_data):
        z = z.unsqueeze(0)  # Add batch dimension
        y = model.decode(z)  # Decode to get reconstruction
        y = y.squeeze(0)  # Remove batch dimension

        # Compute the Jacobian J of the decoder at point z
        J = torch.autograd.functional.jacobian(model.decode, z)[0,:,0,:]

        # Compute the trace of J^T J
        JtJ = J.T @ J
        trace_JtJ = torch.trace(JtJ)

        # Store the trace value as a label for the point
        trace_vals[j] = trace_JtJ.item() / JtJ.shape[0]  # Normalize by the number of dimensions

    p = axs[0, i].scatter(encoded_data[:, 0].cpu(), encoded_data[:, 1].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[0, i].set_title(f'Latent Space (λ={lambda_iso:.3f})')
    axs[0, i].view_init(90, 90, 0)
    # axs[0, i].set_xticks([])
    # axs[0, i].set_yticks([])
    #plot 3d data
    p = axs[1, i].scatter(reconstruction[:, 0].cpu(), reconstruction[:, 1].cpu(), reconstruction[:, 2].cpu(), c=trace_vals, s=5)
    plt.colorbar(p)
    axs[1, i].set_title(f'Reconstruction (λ={lambda_iso:.3f})')

# %%
statses = []
for i, lambda_iso in enumerate(lambda_isos):
    model_path = modelpath(dir_path, lambda_iso, 2)
    model = ConformalAutoencoder(Encoder(input_dim, latent_dim), Decoder(latent_dim, output_dim), lambda_conf=lambda_iso).to(device)
    model.load_state_dict(torch.load(model_path))
    
    model.eval()
    with torch.no_grad():
        encoded_data = model.encode(val_data)
        reconstruction = model.decode(encoded_data)

    statses.append(evaluate_conformality(model, data)[0])

df = pd.DataFrame(statses, index=lambda_isos)
# styled_df = df.style.highlight_min(color='green').highlight_max(color='coral')

# %%
styled_df = df.style \
    .background_gradient(subset=[
            'reconstruction_error',
            'diagonal_gini',
            'lambda_std',
            'lambda_std_normed',
            'off_diag_mean',
            'off_diag_norm',
            'off_diag_mean_normed',
            'off_diag_norm_normed',
            'jTj_minus_lambdaI_mean',
            'jTj_minus_lambdaI_norm',
            'jTj_minus_lambdaI_mean_normed',
            'jTj_minus_lambdaI_norm_normed',
            'determinant_vs_estimate_std',
            ], cmap='Reds') \
    .background_gradient(subset=[
        'determinant_vs_estimate_mean'
    ], cmap='Greens')\
    .background_gradient(subset=[
        'lambda_mean',
        'latent_std',
        'latent_std_max',
        'latent_std_min',
        'latent_norm',
    ], cmap='Blues')

styled_df
# Out:
# <style type="text/css">
# #T_ed786_row0_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_ed786_row0_col1, #T_ed786_row0_col8, #T_ed786_row0_col9, #T_ed786_row0_col12, #T_ed786_row0_col13, #T_ed786_row0_col15, #T_ed786_row1_col0, #T_ed786_row2_col4, #T_ed786_row8_col10, #T_ed786_row8_col11, #T_ed786_row9_col3, #T_ed786_row9_col6, #T_ed786_row9_col7, #T_ed786_row9_col10, #T_ed786_row9_col11 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ed786_row0_col2, #T_ed786_row9_col21, #T_ed786_row9_col22, #T_ed786_row9_col23, #T_ed786_row9_col24 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ed786_row0_col3, #T_ed786_row0_col6, #T_ed786_row0_col7, #T_ed786_row0_col10, #T_ed786_row0_col11, #T_ed786_row1_col4, #T_ed786_row9_col0, #T_ed786_row9_col1, #T_ed786_row9_col8, #T_ed786_row9_col9, #T_ed786_row9_col12, #T_ed786_row9_col13, #T_ed786_row9_col15 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ed786_row0_col4 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_ed786_row0_col14 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ed786_row0_col21, #T_ed786_row0_col22, #T_ed786_row0_col23, #T_ed786_row0_col24, #T_ed786_row9_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ed786_row1_col1 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_ed786_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_ed786_row1_col3 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_ed786_row1_col6, #T_ed786_row1_col7 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_ed786_row1_col8, #T_ed786_row1_col9 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_ed786_row1_col10, #T_ed786_row1_col13 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_ed786_row1_col11, #T_ed786_row3_col0 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_ed786_row1_col12 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_ed786_row1_col14 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_ed786_row1_col15, #T_ed786_row7_col3 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_ed786_row1_col21 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_ed786_row1_col22 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_ed786_row1_col23 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_ed786_row1_col24, #T_ed786_row3_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_ed786_row2_col0, #T_ed786_row8_col3, #T_ed786_row8_col6, #T_ed786_row8_col7 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_ed786_row2_col1, #T_ed786_row2_col3, #T_ed786_row9_col4 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_ed786_row2_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_ed786_row2_col6, #T_ed786_row2_col7, #T_ed786_row5_col8, #T_ed786_row5_col9 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_ed786_row2_col8, #T_ed786_row2_col9 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_ed786_row2_col10, #T_ed786_row2_col11 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_ed786_row2_col12, #T_ed786_row4_col15, #T_ed786_row8_col4 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_ed786_row2_col13 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_ed786_row2_col14 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_ed786_row2_col15 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_ed786_row2_col21, #T_ed786_row2_col22, #T_ed786_row2_col23 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_ed786_row2_col24 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_ed786_row3_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_ed786_row3_col3 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_ed786_row3_col4 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_ed786_row3_col6, #T_ed786_row3_col7 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_ed786_row3_col8, #T_ed786_row3_col9 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_ed786_row3_col10, #T_ed786_row3_col11 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_ed786_row3_col12 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_ed786_row3_col13 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_ed786_row3_col14 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_ed786_row3_col15 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_ed786_row3_col21, #T_ed786_row3_col23 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_ed786_row3_col22, #T_ed786_row4_col24 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_ed786_row3_col24 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_ed786_row4_col0 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_ed786_row4_col1 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_ed786_row4_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_ed786_row4_col3 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_ed786_row4_col4, #T_ed786_row5_col1, #T_ed786_row5_col13 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_ed786_row4_col6, #T_ed786_row4_col7, #T_ed786_row4_col10, #T_ed786_row4_col11 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_ed786_row4_col8, #T_ed786_row4_col9 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_ed786_row4_col12, #T_ed786_row4_col13, #T_ed786_row6_col12 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_ed786_row4_col14 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_ed786_row4_col21 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_ed786_row4_col22 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_ed786_row4_col23, #T_ed786_row5_col24 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_ed786_row5_col0 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_ed786_row5_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ed786_row5_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_ed786_row5_col4 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_ed786_row5_col6, #T_ed786_row5_col7, #T_ed786_row5_col11 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_ed786_row5_col10 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_ed786_row5_col12 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_ed786_row5_col14 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_ed786_row5_col15 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_ed786_row5_col21, #T_ed786_row5_col22, #T_ed786_row5_col23 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_ed786_row6_col0 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_ed786_row6_col1 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ed786_row6_col3 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_ed786_row6_col4 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_ed786_row6_col6, #T_ed786_row6_col7, #T_ed786_row6_col10, #T_ed786_row6_col11 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_ed786_row6_col8, #T_ed786_row6_col9 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col13, #T_ed786_row8_col12 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col14 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col15 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_ed786_row6_col21, #T_ed786_row7_col24 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col22 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col23 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_ed786_row6_col24 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_ed786_row7_col0 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_ed786_row7_col1 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_ed786_row7_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_ed786_row7_col4 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_ed786_row7_col6, #T_ed786_row7_col7, #T_ed786_row7_col10 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_ed786_row7_col8, #T_ed786_row7_col9, #T_ed786_row8_col8, #T_ed786_row8_col9 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_ed786_row7_col11 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #
